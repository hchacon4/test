# %% [markdown]
# <a href="https://colab.research.google.com/github/hchacon4/test/blob/main/bernoulli2_20pipes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ####Notes
# - Using SimData_to_csv notebook to create dataset csv
# - I may want a labels map (dict) for pipe labels like the one here
#   - https://pytorch.org/tutorials/beginner/basics/data_tutorial.html#iterating-and-visualizing-the-dataset
# - Unclear what a one-hot encoded tensor might be used for
#   - used here as a target label transformation
#     - https://pytorch.org/tutorials/beginner/basics/transforms_tutorial.html#lambda-transforms
#
# - How do I handle two labels?
# - Is normalization required?
#  - ans: desirable when features have different ranges. https://medium.com/@urvashilluniya/why-data-normalization-is-necessary-for-machine-learning-models-681b65a05029#:~:text=The%20goal%20of%20normalization%20is,when%20features%20have%20different%20ranges.
# - Complete a panda tutorial
# - He: Classifer tutorial; CIFAR10 dataset (3 channel images)
#  - https://pytorch.org/tutorials/beginner/blitz/cifar10_tutorial.html
# - Colab Pro
#  - One important caveat to remember while using Colab is that the files you upload to it won’t be available forever. Colab is a temporary environment with an idle timeout of 90 minutes and an absolute timeout of 12 hours. This means that the runtime will disconnect if it has remained idle for 90 minutes, or if it has been in use for 12 hours [longer for Colab Pro]. On disconnection, you lose all your variables, states, installed packages, and files and will be connected to an entirely new and clean environment on reconnecting. source:https://neptune.ai/blog/google-colab-dealing-with-files

# %% [markdown]
# ####Model framework

# %%
# %matplotlib inline

import os
import torch
from torch import nn
from torch.nn import functional as F
from torch.utils.data import DataLoader, TensorDataset
from torchvision import datasets, transforms

import pandas as pd   # For loading csv file dataset
import random

import math   # Used for nan checking (math.isnan())

# Straight-Through Estimator
# https://www.hassanaskary.com/python/pytorch/deep%20learning/2020/09/19/intuitive-explanation-of-straight-through-estimators.html

# Autograd
# https://pytorch.org/tutorials/beginner/examples_autograd/two_layer_net_custom_function.html

# Define model
#  -- when called, model returns a output_dim dimensional tensor
# def sparseProbMap(batch_probMap, sparsity) :
def sparseProbMap(probMap, sparsity) :
  """Rescale probability map (batch_probMap) to obtain desired sparsity in
  measuremets that are turned on.
  sparsity = budget (int) / training sample length (meas)
    budget -- number of measurement to turn on/ sensor to deploy
  """
  mean = torch.mean(probMap, dim=0, keepdim=True)
  scalar = sparsity / mean
  beta_scalar = (1 - sparsity) / (1 - mean)
  toggle = torch.le(scalar, 1).float()
  sparse_probMap = ( toggle * scalar * probMap
                      + (1 - toggle) * (1 - (1 - probMap) * beta_scalar) )
  # print(f'sparseProbMap(): samp_means {samp_means}')
  # print(f'sparseProbMap(): samp_means size {samp_means.size()}')
  # print(f'sparseProbMap(): samp_scalars {samp_scalars}')
  # print(f'sparseProbMap(): samp_beta_scalars {samp_beta_scalars}')
  # print(f'sparseProbMap(): sparse_probMap size {sparse_probMap.size()}')
  return sparse_probMap
  
  # Alt approaches
  # torch method -- with prob_map repeat before this func call (i.e. batch_probMap)
  # Notice batch_probMap contains batch_size copies of one prob_map
  #  Might be able to make this even faster by running the calc once, then repeating after this call.
  # Tensor version -- might speed up training time.
  # samp_means = torch.mean(batch_probMap, dim=1, keepdim=True)
  # samp_scalars = sparsity / samp_means
  # samp_beta_scalars = (1 - sparsity) / (1 - samp_means)
  # toggles = torch.le(samp_scalars, 1).float()
  # sparse_probMap = ( toggles * samp_scalars * batch_probMap
  #                     + (1 - toggles) * (1 - (1 - batch_probMap) * samp_beta_scalars) )

  # for samp_probMap in batch_probMap :
  #   mean_sampProbMap = torch.mean(samp_probMap)
  #   scalar_sampProbMap = sparsity / mean_sampProbMap
  #   beta_scalar = (1 - sparsity) / (1 - mean_sampProbMap) # Rename variable to something more descriptive
  #   # print(f'sparseProbMap(): samp_probMap {samp_probMap}')
  #   # print(f'sparseProbMap(): samp_probMap size {samp_probMap.size()}')
  #   # print(f'sparseProbMap(): mean_sampProbMap {mean_sampProbMap}')
  #   # assert False
  #   toggle = torch.le(scalar_sampProbMap, 1).float()
  #   scaled_sampMap = ( toggle * scalar_sampProbMap * samp_probMap
  #                     + (1 - toggle) * (1 - (1-samp_probMap) * beta_scalar) ).reshape([1, -1])
  #   # print(f'sparseProbMap(): scaled_sampMap type {type(scaled_sampMap)}')
  #   if scaled_sampMaps == None :
  #     scaled_sampMaps = torch.cat((scaled_sampMap,), dim=0).to(device)
  #   else :
  #     scaled_sampMaps = torch.cat((scaled_sampMaps, scaled_sampMap,), dim=0).to(device)
  #   # scaled_sampMaps.append(toggle * scalar_sampProbMap * samp_probMap + (1 - toggle) * (1 - (1-samp_probMap) * beta_scalar))
  # # print(f'sparseProbMap(): scaled_sampMaps size {scaled_sampMaps.size()}')

  # NOTE: Dramatic slowdown after incorporating this function.
  #  May be due to use of for loop.
  # Use with scaled_sampMaps list version.
  # One big tensor. I'd prefer rows. Try adding brackets to append statement.
  # print(f'sparseProbMap(): sparse_probMap size {sparse_probMap.size()}')
  # sparse_probMap = torch.cat((scaled_sampMaps,), dim=0)
  # sparse_probMap  = sparse_probMap.reshape([batch_size, -1])
  # assert False
  # return scaled_sampMaps   # Equivalent to sparse_probMap for a batch.

class STEFunction(torch.autograd.Function) :
    """
    We can implement our own custom autograd Functions by subclassing
    torch.autograd.Function and implementing the forward and backward passes
    which operate on Tensors.
    """

    @staticmethod
    def forward(ctx, probability_mask) :
        """
        In the forward pass we receive a Tensor containing the input (prob_mask) and return
        a Tensor containing the output (binary_mask).
        ctx is a context object that can be used
        to stash information for backward computation. You can cache arbitrary
        objects for use in the backward pass using the ctx.save_for_backward method.
        """
        # Push probability map through a bernoulli sampling to create 0/1 mask.
        # Return mask.

        prob_mask_size = probability_mask.size()
        # print(f'STEFunc() forward(): prob_mask_size {prob_mask_size}')
        # print(f'STEFunc() forward(): batch_size {batch_size}')

        # Bernoulli sampling.
        # Sample from a uniform distribution.
        # uni_samples = probability_mask.new_empty(prob_mask_size).uniform_()
        uni_samples = probability_mask.new_empty(prob_mask_size).uniform_()
        # Bernoulli sampled binary mask.
        binary_mask = (probability_mask > uni_samples).float()
        # Note the different sizes of probability_mask and uni_sample. The
        #  following operation returns a tensor shaped like uni_sample.
        # Note: torch.bernoulli() is not usable because func return only the prob mask,
        #  but the uniform distributions samples are needed for gradient calcs.
        # bin_mask = torch.bernoulli(probablility_mask)
        # print(f'STEFunc() forward(): bin_mask_size {binary_mask.size()}')
        # print(f'STEFunc() forward(): probability_mask {probability_mask},\n\tuni_samples {uni_samples}')
        # assert False

        ctx.save_for_backward(probability_mask, uni_samples)
        return binary_mask
    
    @staticmethod
    def backward(ctx, grad_output) :
      # return F.hardtanh(grad_output)
      # SigDeriv graph: https://www.desmos.com/calculator/icbxupp3dh
      alpha = 1
      prob_mask, uni_samples = ctx.saved_tensors

      # Sigmoid function derivative
      grad_est = (alpha * torch.exp(-alpha * (prob_mask - uni_samples))
          / (1 + torch.exp(-alpha * (prob_mask - uni_samples))) ** 2)
          # / torch.exp(1 + -alpha * (prob_mask - uni_samples)) ** 2)
      return grad_est * grad_output

class StraightThroughEstimator(nn.Module) :
  def __init__(self) :
    # Consider moving probability map parameters here.
    #  If so, change STEFunction call.
    super(StraightThroughEstimator, self).__init__()
  
  def forward(self, probability_mask) :
    binary_mask = STEFunction.apply(probability_mask)
  # def forward(self, probability_mask, batch_size) :
    # binary_mask = STEFunction.apply(probability_mask, batch_size)
    return binary_mask

class Encoder(nn.Module):
    # Consider removing the default parameter values.
    def __init__(self, input_dim=0, output_dim=0):
        super(Encoder, self).__init__()
        self.flatten = nn.Flatten()
        # Note: nn.Sequential may take only a single argument. A tuple may work,
        #  but unclear if this is stable.
        self.binary_STE_stack = nn.Sequential(
            # Define the input dimensions
            # STE is placed at the bottleneck of the autoencoder.
            StraightThroughEstimator(),
        )
        # self.ste = StraightThroughEstimator()
        # self.steFunc = STEFunction().apply
        self.sparProbMapFunc = sparseProbMap
        unif_samp_tn = torch.zeros([input_dim]).uniform_()
        self.mask_params = nn.Parameter(unif_samp_tn)
        # fill_val_tn = torch.zeros([input_dim]).fill_(0.5)
        # self.mask_params = nn.Parameter(fill_val_tn)

    def forward(self, x):
        x = self.flatten(x)
        prob_mask = torch.sigmoid(self.mask_params)   # Ensures probabilities lie btwn (0, 1)
        batch_size = x.size()[0]
        # Used to create bin_mask for ea training sample.
        #  To switch to one bin_mask per batch, comment out the following line.
        # prob_mask = prob_mask.repeat(batch_size, 1)
        sparse_probMask = self.sparProbMapFunc(prob_mask, sparsity=0.012)
        sparse_probMask = sparse_probMask.repeat(batch_size, 1)
        # sparse_probMask = prob_mask.repeat(batch_size, 1)
        # Using a tuple input is problematic because the model expects a grad for all inputs to nn.Sequential.
        binary_mask = self.binary_STE_stack(sparse_probMask)
        # binary_mask = self.binary_STE_stack(prob_mask)
        # binary_mask = self.ste(prob_mask)
        # binary_mask = self.steFunc(prob_mask)
        # print(f'Encoder.forward(): prob_mask size {prob_mask.size()}')
        # print(f'Encoder.forward(): prob_mask size {prob_mask}')
        # assert False
        # print(x.size())
        # print(f'Encoder.forward(): mask_params {self.mask_params}')
        # print('Encoder.forward(): batch_size', batch_size)
        # print('Encoder.forward(): binary_mask', binary_mask)
        return x * binary_mask, binary_mask, self.mask_params

    # May or may not need to define the backward behavior of this class.
    # def backward(self, x):
    #     pass
    
class Decoder(nn.Module):
    def __init__(self, input_dim, output_dim):   # output_dim is not yet used.
        super(Decoder, self).__init__()
        self.flatten = nn.Flatten()
        self.linear_lrelu_stack = nn.Sequential(
            # Define the input dimensions
            nn.Linear(input_dim, 512),
            # nn.Linear(input_dim, output_dim),
            nn.LeakyReLU(),
            # nn.Linear(512, 512),
            # nn.LeakyReLU(),
            # nn.Linear(512, 512),
            # nn.LeakyReLU(),
            # nn.Linear(512, 512),
            # nn.LeakyReLU(),
            # nn.Linear(512, 512),
            # nn.LeakyReLU(),
            # nn.Linear(512, 512),
            # nn.LeakyReLU(),
            # # Define the output dimensions
            nn.Linear(512, output_dim),
            nn.LeakyReLU(),
        )
        # Yisong: initialize the weights in the first layer, and the following layers will follow suit.
        # self.linear_lrelu_stack[0].weight.data /= 100.

    def forward(self, x):
        x = self.flatten(x)
        # print(x.size())
        logits = self.linear_lrelu_stack(x)
        return logits

class Autoencoder(nn.Module) :
    def __init__(self, input_dim, output_dim) :
        super(Autoencoder, self).__init__()
        # self.auto_stack = nn.Sequential(
        #     Encoder(input_dim, output_dim),
        #     Decoder(),
        # )
        self.encoder = Encoder(input_dim=input_dim)
        self.decoder = Decoder(input_dim, output_dim)

    def forward(self, x, binMaskSizeLs=[], encode=False, decode=False) :
        if encode :
            pass
        elif decode :
            pass
        else :
            # x = self.auto_stack(x)
            under_samp_meas, binary_mask, mask_params = self.encoder(x)
            # Working out what to do with the binary_mask -- i.e. if it will be fed to decoder or not.
            bin_mask_size = binary_mask.sum()
            batch_size = x.size()[0]
            # binMaskSizeLs.append(bin_mask_size)
            # print(f'AE forward(): avg binary_mask size {int(bin_mask_size / batch_size)}')
            # print(f'Auto.forward(): mask_params {mask_params}')
            x = self.decoder(under_samp_meas)
        return x, mask_params

# Get cpu or gpu device for training.
device = "cuda" if torch.cuda.is_available() else "cpu"
print("Using {} device".format(device))
# Out:
# Using cuda device

# %%
# input_dim = 10
# init_tensor = torch.zeros([input_dim]).uniform_()
# print(init_tensor)
# p_mask = nn.Parameter(init_tensor)
# print(p_mask)
# ste = STEFunction()
# print(ste)
# masks = ste.forward(init_tensor, p_mask)
# a = torch.randn(1, 2, 3, 4)
# b = torch.randn(2, 2)
# print(a)
# print(a.size())
# print(a.view(1, 1, 2, 3, 2, 2))
# print(b)
# print(b * a.view(1, 1, 2, 3, 2, 2))

# Create a mask for each sample by first creating a uniform value tn of size
#  [batch_size, prob_mask_size], then 
# c = torch.zeros([10]).uniform_()
# print(c)
# tn = c.new_empty([3, 10]).uniform_()
# print(tn)
# bin_mask = (c > tn).float()
# print(bin_mask)
# End "Create a mask ..."

# print(c)
# mask = STEFunction.forward(c, c)   # Comment out ctx line.
# print(mask)   # OK
# module = StraightThroughEstimator()
# mask = module(c)
# print(mask)
# module1 = Encoder(input_dim=10)
# meas = torch.randint(100, (10,))
# print(meas)
# mask = module1(meas)
# print(mask)   # OK

# %% [markdown]
# ####Training and Testing

# %%
def train_loop(dataloader, model, loss_fn, optimizer, epoch=0, mod=100):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)   # For avg training loss
    # print(f'train_loop(): dataset size: {size}')
    # print(f'train_loop(): num_batches: {num_batches}')
    train_loss, train_accuracy = 0, 0
    confusion_matrix = torch.zeros(20, 20, dtype=torch.int32)
    prevLoss = 100.
    for batch, (X, y) in enumerate(dataloader):
        # print(batch, X)
        # print(y)
        X = X.to(device)
        y = y.to(device)
        # Compute prediction and loss
        pred, prob_params = model(X)  # params for flexibility
        # print(y.size())
        # print(pred.size())
        # print(pred)
        # print(prob_params)
        
        if (epoch < 10000) :
          # prob_mask * X -> classifier -> pred
          # # print(f"mask_params {model.state_dict()['encoder.mask_params']}")
          # prob_params = model.state_dict()['encoder.mask_params']  # could be slower than passing the params out
          prob_map = torch.sigmoid(prob_params)   # Ensures values (probabilities) lie btwn (0, 1)
          splus = nn.functional.softplus(prob_params, -1)   # -log(1 + e^(-x)); careful with the sign when using in expressions.
          # print(splus[0], prob_params[0])   # Sanity check
          # print(torch.max(splus))
          # assert torch.max(splus) < 0
          # print(epoch)
          # loss_KL = ( (1 - prob_map) * torch.log(1 - prob_map) + prob_map * torch.log(prob_map) - torch.log(torch.tensor(0.5)) ).sum()
          # p_m = torch.where(prob_map > 0, prob_map, torch.tensor(0.001).to(device))
          # p_m = torch.where(prob_map < 1, prob_map, torch.tensor(0.999).to(device))
          # # print(f'p_m max {torch.max(p_m)}, min {torch.min(p_m)}')
          # # print(f'p_m range {torch.max(p_m) + abs(torch.min(p_m))}')
          # loss_KL = ( (1 - p_m) * torch.log(1 - p_m) + p_m * torch.log(p_m) - torch.log(torch.tensor(0.5)) ).sum()
          # # loss_KL = ( (1 - p_m) * torch.log(1 - p_m) + p_m * torch.log(p_m) ).sum()
          # loss_KL = lamb * ( (1 - prob_map) * torch.log(1 - prob_map) + prob_map * torch.log(prob_map) ).sum()
          # Natural log is the result of torch.log(...)
          loss_KL = ( (1 - prob_map) * ((-1)*prob_params + splus) + prob_map * splus - torch.log(torch.tensor(0.5)) ).sum()   # includes constant term
          # loss_KL = ( (1 - prob_map) * ((-1)*prob_params + splus) + prob_map * splus ).sum()
          # Dramatic change between including lamb and not may affect learning.
          # lamb = 1 / torch.exp(torch.tensor(-1/250*epoch))   # Try 1 / sqrt(epoch)
          lamb = 1 / epoch   # Try 1 / sqrt(epoch)
          loss_KL = lamb * loss_KL   # Anneal diversity loss
        else :
          loss_KL = 0.0
        # # print(f'loss_KL {loss_KL}')
        # # assert loss_KL != float('nan')
        # assert not math.isnan(loss_KL)

        # **** Notice pred is formed on the batch level, but loss_KL is a one shot ****
        loss = loss_fn(pred, y) + loss_KL  # returns single value; avg loss across batch
        # loss = loss_fn(pred, y)   # returns single value; avg loss across batch
        assert loss != float('nan')
        # loss = loss_fn(pred, y)  # returns single value; avg loss across batch
        # assert False
        # print(loss * len(y))
        # for i in range(len(y)) :
        #   print(pred[i])
        #   print(y[i])
        #   ls = loss_fn(pred[i], y[i])
        #   print(f'loss {i} {ls}')
        # print(y)
        # print(pred.argmax(1).type(y.dtype))
        # # Confusion Matrix
        for i in range(len(y)) :
          preds = pred.argmax(1).type(y.dtype)
          confusion_matrix[y[i]][preds[i]] += 1
        # print(confusion_matrix)
        
        # Top-k predictions
        # torch.topk(input, k, dim=None, largest=True, sorted=True, *, out=None) -> (Tensor, LongTensor)
        k = 1
        # top_k = torch.topk(input=pred, k=k, dim=1,)
        # print(top_k)

        # Disaggregate performance -- save model
        #  goal: extract outliers (in another notebook)
        #  Make into a function.
        # if epoch > 2000 and loss.item() > (prevLoss * 15) :
        # if epoch == 10000 :
        #   print(f'train_loop(): epoch {epoch} -- loss jumped from {prevLoss:.3} to {loss.item():.3}')
        #   torch.save(model.state_dict(), f'/content/drive/MyDrive/Colab Notebooks/Water Distribution Network/Decoder/saved_models/d11_epoch{epoch}_{batch}_{loss.item():.3}.pt')
        # # print(prevLoss)
        # prevLoss = loss.item()
        # print(prevLoss > loss * 20)
        # print(epoch)
        # assert False

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # train_loss += loss_fn(pred, y).item() * len(y)   # I think this second call to loss_fn runs the grad twice. ???
        train_loss += loss.item() * len(y)
        # y.dtype ensures the the operand types match for use w/ comparison operator (sensitive to type)
        train_accuracy += (pred.argmax(1).type(y.dtype) == y).type(torch.float32).sum().item()
        # print(loss)

        if batch % mod == 0:
            # print(batch)
            # print(y)
            # print(pred)
            loss, current = loss.item(), batch * len(X)
            # print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")

    # Save last model
    # if epoch == 10000 :
    #     print(f'train_loop(): epoch {epoch} -- loss jumped from {prevLoss:.3} to {loss.item():.3}')
    #     torch.save(model.state_dict(), f'/content/drive/MyDrive/Colab Notebooks/Water Distribution Network/Decoder/saved_models/d11_epoch{epoch}_{batch}_{loss.item():.3}.pt')

    train_loss /= size    # weighted avg training loss
    train_accuracy /= size
    print(f"Training Error: \n Accuracy: {(100*train_accuracy):>0.1f}%, Avg loss: {train_loss:>8f} \n")
    return train_loss, train_accuracy, confusion_matrix


def test_loop(dataloader, model, loss_fn, out_dim=10):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    # print(f'test dataset size: {size}')
    # print(f'test num_batches: {num_batches}')
    test_loss, test_accuracy = 0, 0
    confusion_matrix = torch.zeros(out_dim, out_dim, dtype=torch.int32)

    with torch.no_grad():
        for X, y in dataloader:
            X = X.to(device)
            y = y.to(device)

            pred, _ = model(X)
            # print(pred)
            # print(y)
            test_loss += loss_fn(pred, y).item()
            # y.dtype ensures the the operand types match for use w/ comparison operator (sensitive to type)
            test_accuracy += (pred.argmax(1).type(y.dtype) == y).type(torch.float32).sum().item()
            # Confusion matrix
            for i in range(len(y)) :
              preds = pred.argmax(1).type(y.dtype)
              confusion_matrix[y[i]][preds[i]] += 1

    test_loss /= num_batches
    test_accuracy /= size
    print(f"Test Error: \n Accuracy: {(100*test_accuracy):>0.1f}%, Avg loss: {test_loss:>8f} \n")
    # return test accuracy percentage for epoch
    return test_accuracy, confusion_matrix

# %% [markdown]
# ####Animator (d2l)

# %%
def use_svg_display():
    """Use the svg format to display a plot in Jupyter."""
    display.set_matplotlib_formats('svg')

# %%
def set_axes(axes, xlabel, ylabel, xlim, ylim, xscale, yscale, legend):
    """Set the axes for matplotlib."""
    axes.set_xlabel(xlabel)
    axes.set_ylabel(ylabel)
    axes.set_xscale(xscale)
    axes.set_yscale(yscale)
    axes.set_xlim(xlim)
    axes.set_ylim(ylim)
    if legend:
        axes.legend(legend)
    axes.grid()

# %%
from matplotlib import pyplot as plt
from IPython import display

class Animator:
    """For plotting data in animation."""
    def __init__(self, xlabel=None, ylabel=None, legend=None, xlim=None,
                 ylim=None, xscale='linear', yscale='linear',
                 fmts=('-', 'm--', 'g-.', 'r:'), nrows=1, ncols=1,
                 figsize=(3.5, 2.5)):
        # Incrementally plot multiple lines
        if legend is None:
            legend = []
      
        self.nrows = nrows
        self.ncols = ncols
        self.figsize = figsize

        self.xlabel = xlabel
        self.ylabel = ylabel
        self.xlim = xlim
        self.ylim = ylim
        self.xscale = xscale
        self.yscale = yscale
        self.legend = legend

        self.X, self.Y, self.fmts = None, None, fmts

    def add(self, x, y):
        # Add multiple data points into the figure
        if not hasattr(y, "__len__"):
            y = [y]
        n = len(y)
        if not hasattr(x, "__len__"):
            x = [x] * n
        if not self.X:
            self.X = [[] for _ in range(n)]
        if not self.Y:
            self.Y = [[] for _ in range(n)]
        for i, (a, b) in enumerate(zip(x, y)):
            if a is not None and b is not None:
                self.X[i].append(a)
                self.Y[i].append(b)

    
    def display_plt(self):
        # Borrowed use_svg_display() implementation from d2l
        use_svg_display()
        # matplot function
        self.fig, self.axes = plt.subplots(self.nrows, self.ncols, figsize=self.figsize)
        if self.nrows * self.ncols == 1:
            self.axes = [self.axes,]
        # Use a lambda function to capture arguments; set_axes in d2l API
        self.config_axes = lambda: set_axes(self.axes[0],
                                            self.xlabel,
                                            self.ylabel,
                                            self.xlim,
                                            self.ylim,
                                            self.xscale, self.yscale, self.legend)
        self.axes[0].cla()
        for x, y, fmt in zip(self.X, self.Y, self.fmts):
            self.axes[0].plot(x, y, fmt)
        self.config_axes()
        display.display(self.fig)
        display.clear_output(wait=True)

        # return self.fig

# %% [markdown]
# ####Confusion Matrix

# %%
# %run /content/drive/MyDrive/'Colab Notebooks'/'Water Distribution Network'/'Input Pipeline'/'Data To File'/SimData_to_csv(hdf)_v1.ipynb
class Conf_Mat() :
  def __init__(self, classes=10) :
    """classes (int): the number of classes in the classifier."""
    self.confusion_matrix = torch.zeros(classes, classes, dtype=torch.int32)
    # Load labels via JSON or csv file.
    self.labels_str = ['P1', 'P10', 'P100', 'P1000', 'P101', 'P1016', 'P102', 'P20', 'P40', 'P1024']
  
  def addValues(self, pred, y) :
    """Add values to the confusion matrix.
    pred (tensor): tensor containing model predictions.
    y (tensor): tensor containing ground truth labels.
    return None
    """
    # Confusion Matrix
    for i in range(len(y)) :
      preds = pred.argmax(1).type(y.dtype)
      confusion_matrix[y[i]][preds[i]] += 1
    print(confusion_matrix)
  
  def displayConfMat(self) :
    pass

def decode_labels() :
  # Time consuming
  # Might be easier to place the encoder in a file and read it here.
  # WARNING: lab_subset order is not consistent.
  # NOTE: sets are not subscriptable
  # net_charac, dir_path, simdata_dir, base_file, base_jfile, simdata_dir, dest_dir, set_size, time_stamp, debug = feat_lab_args()
  # encoded_targets, lab_subset = labels_ds(base_jfile, simdata_dir, set_size, debug)
  return sorted(['P1', 'P10', 'P100', 'P1000', 'P101', 'P1016', 'P102', 'P20', 'P40', 'P1024'])
# print(decode_labels())

# %% [markdown]
# ####Normalization

# %%
def norm(features) :
  # print(f'norm(): {features} size {features.size()}')
  sq_feat = features ** 2
  # print(f'norm(): {sq_feat} size {sq_feat.size()}')
  sum_feat = sq_feat.sum(1)
  # print(f'norm(): {sum_feat} size {sum_feat.size()}')
  norm_feat = torch.sqrt(sum_feat)
  # print(f'norm(): {norm_feat} size {norm_feat.size()}')
  # print(norm_feat.view(features.size(0), 1))
  unit_feat = features / norm_feat.view(features.size(0), 1)
  # print(f'norm(): {unit_feat} size {unit_feat.size()}')
  return unit_feat
# _, observed, __ = SimData(net_char=4, tmstp=80)
# norm(observed)

# %% [markdown]
# ####Subsampling

# %% [markdown]
# #####Mask Generation
# - (1/0) Sensing Mask Vector

# %%
def sensing_mask_rand(feature_vec, max_sense = 30):
  """
  preconditions: feature tensor must be flat.

  Parameters
  feature_vec: feature tensor to be masked
   shape: list of dimensions
  max_sense: randomly choose 1 to max_sense to be 1, rest 0

  returns 0/1 sensing mask tensor of shape feature_vec w/ max_sense elems set to 1 (rest 0)
  """

  # Create (0/1) mask populated w/ max_sense ones
  mask = torch.zeros(feature_vec.size()).to(device)
  # print(mask)
  # indices = torch.randint(len(feature_vec), size=(max_sense,))   # may contain fewer than max_sense unique indices
  # Katie: Randomize indices and choose the first max_sense
  indices = [*range(len(feature_vec))]
  random.shuffle(indices)
  # print(indices)
  # for idx in indices:   # for use with line 16
  for idx in indices[:max_sense]:
    mask[idx] = 1
  # print(mask)

  # Pass features through the mask
  masked_features = feature_vec * mask

  return mask, masked_features.to(device)
# feature_vec = torch.rand([100])
# print(feature_vec)
# mask, masked_feats = sensing_mask_rand(feature_vec)
# print(mask, '\n', masked_feats)

# %%
def sensing_mask_alternate(feature_vec):
  """
  preconditions: feature tensor must be flat.

  Parameters
  feature_vec: feature tensor to be masked

  returns 0/1 sensing mask tensor of shape feature_vec w/ even indexed elems set to 1 (rest 0)
  """

  # Create (0/1) mask populated w/ max_sense ones
  mask = torch.zeros(feature_vec.size()).to(device)
  # print(mask)
  for idx in range(0, feature_vec.size()[0], 2) :
    mask[idx] = 1
  # print(mask)

  # Pass features through the mask
  # masked_features = feature_vec * mask

  # Simplification: This version reduces the size of the feature
  #  vector by half (mask not concat).
  masked_features = feature_vec[0].reshape([1])
  for idx in range(2, feature_vec.size()[0], 2) :
    masked_features = torch.cat((masked_features, feature_vec[idx].reshape([1])))

  return mask, masked_features.to(device)
# feature_vec = torch.rand([100]).to(device)
# print(feature_vec)
# mask, masked_feats = sensing_mask_alternate(feature_vec)
# print(mask, '\n', masked_feats.size(), '\n', masked_feats)

# %% [markdown]
# #####Random subsamples

# %%
def random_subset(meas_tensor, size, seed=None) :
  """Random subset of measurements (fixed seed).
  Must be able to change the cardinality of the subset.
  Algorithm
    create list of indices
    randomize indices
    select first x number of indices (where x is the subset cardinality)
    form a tensor containing the the sample measurements matching those indices.
    return this tensor
  """
  gen = None
  if seed :
    gen = torch.Generator().manual_seed(seed)

  rand_idxs = torch.randperm(meas_tensor.size()[0], generator=gen)
  sub_idxs = rand_idxs[:size]
  # print('random_subset():', sub_idxs, sub_idxs.size())
  subset = meas_tensor[sub_idxs]
  # print(meas_tensor.size())
  return subset.to(device), sub_idxs

# Test code
# X = torch.rand(100)
# rand_sub = random_subset(X, 50, 1000)
# print('random_subset results:', rand_sub)
# print(rand_sub.size())
# assert False

# %%
def rand_sub_dataset(X, size, seed=None) :
  reduced_meas_X = torch.zeros([X.size(0), size]).to(device)
  # print(X.size(0))
  for i in range(len(X)) :
    rand_sub, sub_idxs = random_subset(X[i], size, seed)
    # print('random_subset results:', rand_sub)
    # print(rand_sub.size())
    reduced_meas_X[i] = rand_sub
  return reduced_meas_X, sub_idxs

# Test Code
# X = torch.rand([3, 20])
# size, seed = 10, 1000
# reduced_meas_X, sub_idxs = rand_sub_dataset(X, size, seed)
# # print(sub_idxs)
# for i, idx in enumerate(sub_idxs) :
#   # print(reduced_meas_X[0, i], X[0, idx])
#   if reduced_meas_X[0, i].item() != X[0, idx].item() :
#     raise Exception('rand_sub_dataset(): Error: Value doesnt match.')
# # print(X[0, 307], X[0, 536], X[0, 329])
# # print(reduced_meas_X[0, 0], reduced_meas_X[0, 1], reduced_meas_X[0, 2])
# print('Done!')

# %% [markdown]
# ####Load SimData and form concat dataset

# %%
def SimData(net_char, tmstp) :
  """
  Note: Dataset file generated in SimData_to_csv notebook
   row 0: base_case
   rows 1->set_size: observed; one leak scenario per row; 1hr (out of one week)
   Labels included (last column)
  """

  # Load dataframe
  src_dir = '/content/drive/MyDrive/Colab Notebooks/Water Distribution Network/Input Pipeline/Datasets/'
  leak_pip_ct = 20
  leak_pipes = f'leak_pipes_{leak_pip_ct}/'
  if tmstp :
    ts_dir = f'tmstp{tmstp}/'
  else :
    ts_dir = ''
  # NOTE: double check dataset file name
  if net_char == 0:   dataset_file = 'dataset1000_link_flowrate_area0.01_0.1.csv'
  elif net_char == 1: dataset_file = 'dataset1000_link_headloss_area0.01_0.1.cs'
  elif net_char == 2: dataset_file = 'dataset1000_link_velocity_area0.01_0.1.cs'
  elif net_char == 3: dataset_file = 'dataset1000_node_demand_area0.01_0.1.cs'
  elif net_char == 4: dataset_file = 'dataset1000_node_head_area0.01_0.1.csv'
  elif net_char == 5: dataset_file = 'dataset1000_node_pressure_area0.01_0.1.csv'
  
  data_file = src_dir + leak_pipes + ts_dir + dataset_file
  datast_ds = pd.read_csv(data_file)
  # print(datast_ds.head())
  
  # Separate base_case, raw_data, and encoded labels
  # Base Case
  base_case = torch.tensor(datast_ds.values[0, :-1], dtype=torch.float32).to(device)
  # print(base_case)
  # raw_data
  raw_data = torch.tensor(datast_ds.values[1: , :-1], dtype=torch.float32).to(device)
  print(f'SimData(): raw_data {raw_data.size()}')
  # encoded labels
  labels = torch.tensor(datast_ds['Label'], dtype=torch.long)[1:].to(device)
  print(f'SimData(): labels {labels.size()}')

  return base_case, raw_data, labels
# _, __, ___ = SimData()

# %%
def leakpipe_subset(pipe_ct, raw, enc_labs):
  "Used to limit the number of pipes in the dataset"
  tmp_raw = torch.tensor([[0]]).to(device)   # dim trouble w/ cat
  tmp_labs = torch.tensor([0]).to(device)
  print(tmp_labs.size())

  for i in range(len(enc_labs)):
    if enc_labs[i] < pipe_ct:
      tmp_raw = torch.cat((tmp_raw, raw[i].reshape([444])))
      tmp_labs = torch.cat((tmp_labs, enc_labs[i].reshape([1])))

  return tmp_raw[1:], tmp_labs[1:]

# %%
def cat_net_attr(net_ls, tmstp, residual=False, norm_feats=False) :
  """Creates three flat vectors containing concatinations of base_case, measurement, and label data.
     **If residual is true, don't use norm here.**
     """
  cat_attrs = None
  for net_char in net_ls :
    # base_case, X_raw, encoded_labels
    data = SimData(net_char, tmstp)
    data_ls = list(data)   # Creates 3 elem list from data 3-tuple returned by SimData.

    if residual :   # Residual before normalization of features.
      data_ls[1] -= data_ls[0]
    # print(data_ls[1])
    # assert False
    if norm_feats :   # Normalize each attribute data separtely before cat.
      data_ls[1] = norm(data_ls[1])

    if not cat_attrs :
      cat_attrs = data_ls   # Includes labels. Only needed once.
      # cat_attrs = data   # Creates 3 elem list from data 3-tuple returned by SimData.
      # cat_attrs = list(cat_attrs)
      # if norm_feats :
      #   cat_attrs[1] = norm(data[1])
    else :
      cat_attrs[0] = torch.cat((cat_attrs[0], data_ls[0]))  # Update base_case by cat'ing next net_attr.
      cat_attrs[1] = torch.cat((cat_attrs[1], data_ls[1]), dim=1)   # Update features by cat'ing next net_attr.
      # if norm_feats :   # Normalize ea attribute data separtely, then cat.
      #   cat_attrs[1] = torch.cat((cat_attrs[1], norm(data[1])), dim=1)
      # else :
      #   cat_attrs[1] = torch.cat((cat_attrs[1], data[1]), dim=1)
      # only need one set of label; no need to cat those again.
    # Normalize Features -- all together (i.e. if more than one attribute is cat'ed, all will be norm'ed together)
    # if norm_feats:
      # Raw data normed across all samples
      #  Would it make more sense to normalize ea sample individually?
      # X_raw = torch.nn.functional.normalize(X_raw, dim=0)
      # cat_attrs[1] = norm(cat_attrs[1])
  print('cat_net_attr():', 'Base', cat_attrs[0].size(), 'X', cat_attrs[1].size(), 'Labels', cat_attrs[2].size())
  return cat_attrs   # cat_attrs is a list, but can be expanded by the caller.
# _, __, ___ = cat_net_attr([0, 4], 80, True)
# print(_.size(), __.size(), ___.size())
# assert False

# %%
def cat_data(residual=False, norm_base=False, norm_feats=False, mask=False, net_char=[0], tmstp=None) :
  if isinstance(net_char, int) :
    net_char = [net_char]
  if residual :
    n_fs = False
  base_case, X_raw, encoded_labels = cat_net_attr(net_char, tmstp, residual, norm_feats=n_fs)   # Don't norm_feat in cat_net_attr if residual is true.
  # base_case, X_raw, encoded_labels = SimData(net_char, tmstp)
  # print(f'cat_data(): {base_case}')
  print(f'cat_data(): X_raw max {torch.max(X_raw)}, min {torch.min(X_raw)}')
  print(f'cat_data(): X_raw range {torch.max(X_raw) + abs(torch.min(X_raw))}')
  print(f'cat_data(): X_raw {X_raw.size()}')
  # print(f'cat_data(): X_raw {X_raw[0]}')
  # print(f'cat_data(): base_case {base_case}')
  
  # work in progress
  # X_raw, encoded_labels = leakpipe_subset(10, X_raw, encoded_labels)
  # print(f'cat_data: encoded labels \n{encoded_labels}')
  # print(f'cat_data: encoded labels {encoded_labels.size()}')
  # assert False

  X_cat = None
  norm_str = ''   # Used for debug output
  div_by_base = base_case   # What is this used for?
  # Residual -- handled in cat_net_data
  # if residual:
    # Avoid dividing by zero
    # for idx in range(len(base_case)):
      # if base_case[idx] < 1.0e-12:
      #   div_by_base[idx] = 1.0e-10
    # X_raw = X_raw / div_by_base
    # X_raw -= base_case
    # base_case /= base_case   # might divide by zero
    # pass
  # print(f'cat_data(): X_raw {X_raw[0]}')
  
  # Normalizations
  if norm_base:
    # Normalize base_case
    #  orders of magnitude larger than residual data
    #  v = v / max(||v||_p, epsilon)  where epsilon is a small value that void dividing by zero
    # norm_base_case = torch.nn.functional.normalize(base_case.reshape([1,-1]))
    base_case = torch.nn.functional.normalize(base_case, dim=0) * 10.0   # Out-dated, use with caution.
    norm_str = 'norm_'
  # if norm_feats:
  #   # Raw data normed across all samples
  #   #  Would it make more sense to normalize ea sample individually?
  #   # X_raw = torch.nn.functional.normalize(X_raw, dim=0)
  #   X_raw = norm(X_raw)
  # print(f'cat_data(): {norm_str}base_case {base_case.size()}')
  # # print(f'cat_data(): {norm_str}base_case {base_case}')

  # I think I can move if mask outer and elim the for loop.
  for feature_vec in X_raw:
    if mask :
      # Mask and masked features
      #  May want sensing_mask_rand() that can process batches of samples
      # mask_tn, masked_feats = sensing_mask_rand(feature_vec)
      # Construct feature set from concatination of base_case, mask, and masked measuremnts.
      # temp = torch.cat((masked_feats.to(device), mask.to(device), base_case.to(device))).reshape([1,-1])
      # base_case measurements not included
      # temp = torch.cat((masked_feats.to(device), mask_tn.to(device))).reshape([1, -1])
      # Simplification: notice feature vector size is halved. Update col variable accordingly.
      mask_tn, masked_feats = sensing_mask_alternate(feature_vec)
      # Not Needed. Adjust size of label vector.
      # masked_labels = encoded_labels[0].reshape([1])
      # print(encoded_labels.size())
      # assert False
      # for idx in range(2, encoded_labels.size()[0], 2) :
      #   masked_labels = torch.cat((masked_labels, encoded_labels[idx].reshape([1])))
      temp = masked_feats.reshape([1,-1])
      # encoded_labels = masked_labels
      # print(f'cat_data(), mask: enc_lab size {encoded_labels.size()}')

    else :
      # Features (no mask)
      # Construct feature set from concatination of base_case and observed measuremnts.
      # temp = torch.cat((feature_vec.to(device), base_case.to(device))).reshape([1,-1])
      # I don't think this is doing anything.  Check if X_raw is changed by this. May already be a flat tensor after cat_net_attrs call.
      temp = feature_vec.reshape([1,-1])
    # print(f'cat_data(): temp {temp}')

    if X_cat is None:
      X_cat = temp
      # print(X_cat)
    else:  
      X_cat = torch.cat((X_cat, temp))
      # print(X_cat)

  print(f'cat_data(): X_cat {X_cat.size()}')
  # print(f'cat_data(): X_cat {X_cat[0]}')
  # assert False
  return X_cat, encoded_labels   # Not returning base_case at this time.
# print(f'output: {cat_data(residual=True, norm_base=False, norm_feats=False, mask=False)}')
# assert False

# %% [markdown]
# ####Train the model

# %% [markdown]
# #####Set-up Training

# %%
rows = 0
cols = 0
input_dim = 0
output_dim = 0

tr_dataset = None
ts_dataset = None

# %%
from collections import Counter
import statistics as stats

def histo_pipe_dist(labels) :
  """Display histogram of leakpipe distribution.
  labels (tensor) : pytorch tensor of labels (ints).
  Note: requires matplotlib and Pandas.
  """
  # Histo
  Y = pd.Series(labels.cpu())
  recounted = Counter(Y)
  print(recounted)
  std = stats.stdev(recounted.values())
  print(f'stdev {std:.2}')
  Y.plot.hist(grid=True, bins=10, alpha=0.7, rwidth=0.8, color='#607c8e', align='mid')
  plt.title(f'Label Frequency for {len(Y)} Samples')
  plt.xlabel('Label')
  plt.grid(axis='x')
  # plt.text(6, 200, r'class 5 = 229 (46%)')
  # assert False
  return std

# %%
def randomize_dataset(X, y) :
  random.seed(10343)
  ls = []
  for i in range(len(y)) :
    zipped = X[i], y[i]
    # print(zipped, end=" ")
    ls.append(zipped)
  # print('randomize_dataset(): ls', len(ls))
  random.shuffle(ls)
  shuf_X = torch.empty([1, len(X[0])]).to(device)
  # print(shuf_X.size(), shuf_X)
  shuf_y = torch.empty([1], dtype=torch.long).to(device)
  # print(shuf_X.size(), shuf_X)
  for feat, label in ls :
    # print('randomize_dataset(): feat', feat.reshape([1, -1]).size())
    shuf_X = torch.cat((shuf_X, feat.reshape([1, -1])))
    # print('randomize_dataset(): label', label.reshape([1]).size())
    # label = torch.tensor(label, dtype=torch.long).to(device)
    shuf_y = torch.cat( (shuf_y, label.reshape([1])) )
  # print(shuf_X)
  # print(shuf_y)
  # print('randomize_dataset(): shuf_X', shuf_X.size())
  # print('randomize_dataset(): shuf_y', shuf_y.size())
  return shuf_X[1:], shuf_y[1:]

# %%
def find_seed(X, y, tr_size, tr_or_ts) :
  min_std = 100
  # tr_or_ts = 0  # tr = 0, ts = 1
  for i in range(20, 150) :
    print(i)
    subsets = torch.utils.data.random_split(TensorDataset(X, y),
                                            [tr_size, len(y) - tr_size],
                                            generator=torch.Generator().manual_seed(i),
                                            )
    # print(len(subsets),
    #       subsets[1].dataset.tensors[1].size(),
    #       type(subsets[1].indices),
    #       len(subsets[1].indices),
    #       subsets[1].dataset.tensors[1][[i for i in subsets[1].indices]],
    #       )
    std = histo_pipe_dist(subsets[tr_or_ts].dataset.tensors[1][[i for i in subsets[tr_or_ts].indices]])
    if std < min_std :
      min_std = std
      seed = i
  print(seed)
  return seed

# %% [markdown]
# #####MNISTfashion set

# %%
# mnist
"""
tr_dataset = datasets.FashionMNIST(
    root="data",
    train=True,
    download=True,
    transform=transforms.ToTensor()
)

ts_dataset = datasets.FashionMNIST(
    root="data",
    train=False,
    download=True,
    transform=transforms.ToTensor()
)

rows = 28
cols = 28
input_dim = rows*cols
output_dim = 10

learning_rate = 1e-3
epochs = 10
batch_size = 64
mod = 100
#"""
# Out:
# '\ntr_dataset = datasets.FashionMNIST(\n    root="data",\n    train=True,\n    download=True,\n    transform=transforms.ToTensor()\n)\n\nts_dataset = datasets.FashionMNIST(\n    root="data",\n    train=False,\n    download=True,\n    transform=transforms.ToTensor()\n)\n\nrows = 28\ncols = 28\ninput_dim = rows*cols\noutput_dim = 10\n\nlearning_rate = 1e-3\nepochs = 10\nbatch_size = 64\nmod = 100\n#'

# %% [markdown]
# #####SimData Loading

# %%
# Network characterist options:
#  {0: '/link_flowrate', 1: '/link_headloss', 2: '/link_velocity',
#   3: '/node_demand', 4: '/node_head', 5: '/node_pressure'}
residual = True  # Subtract measured from base_case; 0 if normal behavior, else non-zero.
norm_base = False
norm_feats = True   
mask = False
net_char = 0
tmstp = 80
cat_attrs = True
subsample = False
if cat_attrs :
  net_char = [0, 4]
X, y = cat_data(residual, norm_base, norm_feats, mask, net_char, tmstp)
# print(y)
# torch.set_printoptions(edgeitems=50)
# print(f'Training Set: X[0] {X[0]}')

# Visualize the dataset leak pipe distribution.
# histo_pipe_dist(y)

if subsample :
  perc_of_meas = 0.01
  size = int(X.size(1) * perc_of_meas)
  print('subsample: size ', size)
  seed = 1001
  reduced_meas_X, __ = rand_sub_dataset(X, size, seed)
  print('subsample:', reduced_meas_X.size())
  # print(X[0, 307], X[0, 536], X[0, 329])
  # print(reduced_meas_X[0, 0], reduced_meas_X[0, 1], reduced_meas_X[0, 2])
  X = reduced_meas_X

torch.set_printoptions(edgeitems=3)
tr_size = int(len(X)*0.7)
ts_size = len(y) - tr_size
# tr_dataset = TensorDataset(X[:split_idx], y[:split_idx])
# ts_dataset = TensorDataset(X[split_idx:], y[split_idx:])
# Find a seed that creates a training set pipe distribution with smallest stdev.
seed = 135   # find_seed prints and returns best seed.
# seed = find_seed(X, y, tr_size, 0)   # Commented out to eliminate the overhead of looking for a seed everytime.
# assert False
tr_dataset, ts_dataset = torch.utils.data.random_split(TensorDataset(X, y),
                                        [tr_size, ts_size],
                                        generator=torch.Generator().manual_seed(seed),
                                        )

# X, y = randomize_dataset(X, y)
# histo_pipe_dist(y[:split_idx])
# histo_pipe_dist(y[split_idx:])
idx = tr_dataset.indices
histo_pipe_dist(tr_dataset.dataset.tensors[1][[i for i in idx]])

# Determine learning rate and measurement vector size
if net_char == 0:
  # link_flowrate
  cols = 444   # links = 444; junctions = 396
  # learning_rate = 9e-3   # single layer
  learning_rate = 8e-2
if net_char == 2:
  # link_velocity
  cols = 444   # links = 444; junctions = 396
  learning_rate = 2e-7
elif net_char == 3:
  # node_demand
  cols = 396   # links = 444; junctions = 396
  learning_rate = 2e-6
  epochs = 2000
elif net_char == 4:
  # node_head
  cols = 396   # links = 444; junctions = 396
  learning_rate = 7e-2
  epochs = 2000
elif net_char == 5:
  # node_pressure
  cols = 396   # links = 444; junctions = 396
  learning_rate = 1e-3
elif isinstance(net_char, list) :
  if norm_feats and cat_attrs :
    learning_rate = 2e-2
  else :
    learning_rate = 8e-2   #(f, h, nf, nh, f+h)

# Determine number of concatenated vectors. Used for determining input_dim
concats = 1
if mask :
  concats = 1

elif norm_feats :
  pass
# Simplification adjustments
cols = X.size(1)
print(f'cols {cols}')


rows = 1
input_dim = rows*cols*concats
output_dim = 20
epochs = 100000
batch_size = 128
mod = 5

# Instantiate model framework
# model = Decoder(input_dim, output_dim).to(device)
model = Autoencoder(input_dim, output_dim).to(device)
print(model)
# print(*model.parameters())
# print(f"mask_params {model.state_dict()['encoder.mask_params'].size()}")
# assert False
# Out:
# SimData(): raw_data torch.Size([1000, 444])
# SimData(): labels torch.Size([1000])
# SimData(): raw_data torch.Size([1000, 396])
# SimData(): labels torch.Size([1000])
# cat_net_attr(): Base torch.Size([840]) X torch.Size([1000, 840]) Labels torch.Size([1000])
# cat_data(): X_raw max 40.62992858886719, min -14.938858032226562
# cat_data(): X_raw range 55.56878662109375
# cat_data(): X_raw torch.Size([1000, 840])
# cat_data(): X_cat torch.Size([1000, 840])
# Counter({5: 46, 18: 41, 1: 39, 14: 37, 11: 37, 10: 37, 0: 36, 8: 35, 12: 35, 2: 35, 13: 35, 3: 35, 9: 34, 4: 33, 17: 33, 7: 31, 15: 31, 19: 31, 16: 30, 6: 29})
# stdev 4.0
# cols 840
# Autoencoder(
#   (encoder): Encoder(
#     (flatten): Flatten(start_dim=1, end_dim=-1)
#     (binary_STE_stack): Sequential(
#       (0): StraightThroughEstimator()
#     )
#   )
#   (decoder): Decoder(
#     (flatten): Flatten(start_dim=1, end_dim=-1)
#     (linear_lrelu_stack): Sequential(
#       (0): Linear(in_features=840, out_features=512, bias=True)
#       (1): LeakyReLU(negative_slope=0.01)
#       (2): Linear(in_features=512, out_features=20, bias=True)
#       (3): LeakyReLU(negative_slope=0.01)
#     )
#   )
# )

# %% [markdown]
# #####Training

# %%
# Initialize the loss function
#  nn.CrossEntropyLoss() encapsulates nn.LogSoftmax and nn.NLLLoss
loss_fn = nn.CrossEntropyLoss()
# Parameter adjustment protocol
# He: always start w/ Adam optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# For plotting results
animator = Animator(xlabel='epoch', xlim=[1, epochs], ylim=[0.0, 1.0],
                        legend=['train loss', 'train acc', 'test acc'])
binMaskSizeLs = []

for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train_dataloader = DataLoader(tr_dataset, batch_size=batch_size, shuffle=False)
    # for x,y in train_dataloader:
    #   print(x,y)
    #   break
    tr_loss, __, _ConfM_ = train_loop(train_dataloader, model, loss_fn, optimizer, epoch=t+1, mod=mod)
    train_metrics = (tr_loss, __)

    # Disaggregate data -- save models; note epoch
    # if t > 2000 and tr_loss > prevLoss * 10 :
    #   print(f'train_loop(): epoch {t} -- loss jumped from {prevLoss:.3} to {tr_loss:.3}')
    #   torch.save(model.state_dict(), f'/content/drive/MyDrive/Colab Notebooks/Water Distribution Network/Decoder/saved_models/d11_epoch{t}.pt')
    # prevLoss = tr_loss

    test_dataloader = DataLoader(ts_dataset, batch_size=batch_size)
    test_acc, confusion_matrix = test_loop(test_dataloader, model, loss_fn, out_dim=output_dim)
    # animator
    animator.add(t + 1, train_metrics + (test_acc,))
torch.save(model.state_dict(), f'/content/drive/MyDrive/Colab Notebooks/Water Distribution Network/Decoder/saved_models/testing_display_of_sensor_grid.pt')
# Not sure the following block is necessary
# train_loss, train_acc = train_metrics
# assert train_loss < 0.5, train_loss
# assert train_acc <= 1 and train_acc > 0.7, train_acc
# assert test_acc <= 1 and test_acc > 0.7, test_acc
print("Done!")
# Out:
# Streaming output truncated to the last 5000 lines.
# -------------------------------
# Training Error:
#  Accuracy: 93.3%, Avg loss: 0.210329
#
# Test Error:
#  Accuracy: 78.3%, Avg loss: 2.261839
#
# Epoch 99377
# -------------------------------
# Training Error:
#  Accuracy: 93.4%, Avg loss: 0.208892
#
# Test Error:
#  Accuracy: 79.3%, Avg loss: 2.287448
#
# Epoch 99378
# -------------------------------
# Training Error:
#  Accuracy: 94.1%, Avg loss: 0.200776
#
# Test Error:
#  Accuracy: 79.0%, Avg loss: 2.252288
#
# Epoch 99379
# -------------------------------
# Training Error:
#  Accuracy: 93.6%, Avg loss: 0.197270
#
# Test Error:
#  Accuracy: 79.0%, Avg loss: 2.295990
#
# Epoch 99380
# -------------------------------
# Training Error:
#  Accuracy: 94.1%, Avg loss: 0.214364
#
# Test Error:
#  Accuracy: 78.7%, Avg loss: 2.157181
#
# Epoch 99381
# -------------------------------
# Training Error:
#  Accuracy: 94.6%, Avg loss: 0.185267
#
# Test Error:
#  Accuracy: 79.3%, Avg loss: 2.256640
#
# Epoch 99382
# -------------------------------
# Training Error:
#  Accuracy: 93.4%, Avg loss: 0.200494
#
# Test Error:
#  Accuracy: 77.0%, Avg loss: 2.345185
#
# Epoch 99383
# -------------------------------
# Training Error:
#  Accuracy: 93.9%, Avg loss: 0.202902
#
# Test Error:
#  Accuracy: 79.0%, Avg loss: 2.269311
#
# Epoch 99384
# -------------------------------
# Training Error:
#  Accuracy: 93.6%, Avg loss: 0.200564
#
# Test Error:
#  Accuracy: 77.7%, Avg loss: 2.306835
#
# Epoch 99385
# -------------------------------
# Training Error:
#  Accuracy: 93.9%, Avg loss: 0.191410
#
# Test Error:
#  Accuracy: 79.3%, Avg loss: 2.258827
#
# Epoch 99386
# -------------------------------
# Training Error:
#  Accuracy: 94.4%, Avg loss: 0.181762
#
# Test Error:
#  Accuracy: 79.7%, Avg loss: 2.235953
#
# Epoch 99387
# -------------------------------
# Training Error:
#  Accuracy: 92.0%, Avg loss: 0.219866
#
# Test Error:
#  Accuracy: 76.3%, Avg loss: 2.241828
#
# Epoch 99388
# -------------------------------
# Training Error:
#  Accuracy: 93.4%, Avg loss: 0.227268
#
# Test Error:
#  Accuracy: 80.0%, Avg loss: 2.208127
#
# Epoch 99389
# -------------------------------
# Training Error:
#  Accuracy: 94.0%, Avg loss: 0.191391
#
# Test Error:
#  Accuracy: 78.3%, Avg loss: 2.194879
#
# Epoch 99390
# -------------------------------
# Training Error:
#  Accuracy: 94.7%, Avg loss: 0.202391
#
# Test Error:
#  Accuracy: 79.7%, Avg loss: 2.145663
#
# Epoch 99391
# -------------------------------
# Training Error:
#  Accuracy: 94.3%, Avg loss: 0.181922
#
# Test Error:
#  Accuracy: 78.7%, Avg loss: 2.172497
#
# Epoch 99392
# -------------------------------
# Training Error:
#  Accuracy: 93.0%, Avg loss: 0.221556
#
# Test Error:
#  Accuracy: 78.0%, Avg loss: 2.174853
#
# Epoch 99393
# -------------------------------
# Training Error:
#  Accuracy: 93.4%, Avg loss: 0.190678
#
# Test Error:
#  Accuracy: 80.0%, Avg loss: 2.142948
#
# Epoch 99394
# -------------------------------
# Training Error:
#  Accuracy: 94.3%, Avg loss: 0.202125
#
# Test Error:
#  Accuracy: 78.0%, Avg loss: 2.101655
#
# Epoch 99395
# -------------------------------
# Training Error:
#  Accuracy: 94.1%, Avg loss: 0.189370
#
# Test Error:
#  Accuracy: 78.3%, Avg loss: 2.201399
#
# Epoch 99396
# -------------------------------
# Training Error:
#  Accuracy: 93.4%, Avg loss: 0.215583
#
# Test Error:
#  Accuracy: 79.7%, Avg loss: 2.182701
#
# Epoch 99397
# -------------------------------
# Training Error:
#  Accuracy: 93.3%, Avg loss: 0.188951
#
# Test Error:
#  Accuracy: 78.3%, Avg loss: 2.237758
#
# Epoch 99398
# -------------------------------
# Training Error:
#  Accuracy: 93.3%, Avg loss: 0.192601
#
# Test Error:
#  Accuracy: 79.0%, Avg loss: 2.224080
#
# Epoch 99399
# -------------------------------
# Training Error:
#  Accuracy: 93.7%, Avg loss: 0.187230
#
# Test Error:
#  Accuracy: 79.0%, Avg loss: 2.239440
#
# Epoch 99400
# -------------------------------
# Training Error:
#  Accuracy: 93.9%, Avg loss: 0.183654
#
# Test Error:
#  Accuracy: 78.0%, Avg loss: 2.248139
#
# Epoch 99401
# -------------------------------
# Training Error:
#  Accuracy: 94.0%, Avg loss: 0.188403
#
# Test Error:
#  Accuracy: 79.0%, Avg loss: 2.247262
#
# Epoch 99402
# -------------------------------
# Training Error:
#  Accuracy: 94.3%, Avg loss: 0.181112
#
# Test Error:
#  Accuracy: 77.0%, Avg loss: 2.219370
#
# Epoch 99403
# -------------------------------
# Training Error:
#  Accuracy: 94.6%, Avg loss: 0.182116
#
# Test Error:
#  Accuracy: 80.7%, Avg loss: 2.192761
#
# Epoch 99404
# -------------------------------
# Training Error:
#  Accuracy: 93.3%, Avg loss: 0.195551
#
# Test Error:
#  Accuracy: 76.7%, Avg loss: 2.170774
#
# Epoch 99405
# -------------------------------
# Training Error:
#  Accuracy: 93.3%, Avg loss: 0.188434
#
# Test Error:
#  Accuracy: 78.7%, Avg loss: 2.172367
#
# Epoch 99406
# -------------------------------
# Training Error:
#  Accuracy: 94.1%, Avg loss: 0.201605
#
# Test Error:
#  Accuracy: 79.7%, Avg loss: 2.186018
#
# Epoch 99407
# -------------------------------
# Training Error:
#  Accuracy: 93.7%, Avg loss: 0.197985
#
# Test Error:
#  Accuracy: 78.3%, Avg loss: 2.234787
#
# Epoch 99408
# -------------------------------
# Training Error:
#  Accuracy: 94.0%, Avg loss: 0.186750
#
# Test Error:
#  Accuracy: 78.0%, Avg loss: 2.243592
#
# Epoch 99409
# -------------------------------
# Training Error:
#  Accuracy: 94.7%, Avg loss: 0.203428
#
# Test Error:
#  Accuracy: 78.0%, Avg loss: 2.217730
#
# Epoch 99410
# -------------------------------
# Training Error:
#  Accuracy: 93.6%, Avg loss: 0.186264
#
# Test Error:
#  Accuracy: 78.7%, Avg loss: 2.059830
#
# Epoch 99411
# -------------------------------
# Training Error:
#  Accuracy: 94.6%, Avg loss: 0.192842
#
# Test Error:
#  Accuracy: 79.7%, Avg loss: 2.150558
#
# Epoch 99412
# -------------------------------
# Training Error:
#  Accuracy: 93.6%, Avg loss: 0.195709
#
# Test Error:
#  Accuracy: 78.0%, Avg loss: 2.184931
#
# Epoch 99413
# -------------------------------
# Training Error:
#  Accuracy: 94.9%, Avg loss: 0.175138
#
# Test Error:
#  Accuracy: 79.7%, Avg loss: 2.084494
#
# Epoch 99414
# -------------------------------
# Training Error:
#  Accuracy: 94.3%, Avg loss: 0.175451
#
# Test Error:
#  Accuracy: 77.3%, Avg loss: 2.089566
#
# Epoch 99415
# -------------------------------
# Training Error:
#  Accuracy: 93.9%, Avg loss: 0.195239
#
# Test Error:
#  Accuracy: 78.0%, Avg loss: 2.151428
#
# Epoch 99416
# -------------------------------
# Training Error:
#  Accuracy: 93.4%, Avg loss: 0.187182
#
# Test Error:
#  Accuracy: 78.0%, Avg loss: 2.089945
#
# Epoch 99417
# -------------------------------
# Training Error:
#  Accuracy: 94.1%, Avg loss: 0.188738
#
# Test Error:
#  Accuracy: 79.3%, Avg loss: 2.201893
#
# Epoch 99418
# -------------------------------
# Training Error:
#  Accuracy: 93.0%, Avg loss: 0.203285
#
# Test Error:
#  Accuracy: 78.3%, Avg loss: 2.241962
#
# Epoch 99419
# -------------------------------
# Training Error:
#  Accuracy: 94.9%, Avg loss: 0.197981
#
# Test Error:
#  Accuracy: 80.3%, Avg loss: 2.164825
#
# Epoch 99420
# -------------------------------
# Training Error:
#  Accuracy: 93.3%, Avg loss: 0.183212
#
# Test Error:
#  Accuracy: 77.3%, Avg loss: 2.201706
#
# Epoch 99421
# -------------------------------
# Training Error:
#  Accuracy: 93.9%, Avg loss: 0.194720
#
# Test Error:
#  Accuracy: 79.0%, Avg loss: 2.188787
#
# Epoch 99422
# -------------------------------
# Training Error:
#  Accuracy: 93.0%, Avg loss: 0.229468
#
# Test Error:
#  Accuracy: 77.3%, Avg loss: 2.282563
#
# Epoch 99423
# -------------------------------
# Training Error:
#  Accuracy: 93.7%, Avg loss: 0.211845
#
# Test Error:
#  Accuracy: 79.7%, Avg loss: 2.187755
#
# Epoch 99424
# -------------------------------
# Training Error:
#  Accuracy: 92.6%, Avg loss: 0.206630
#
# Test Error:
#  Accuracy: 75.7%, Avg loss: 2.179634
#
# Epoch 99425
# -------------------------------
# Training Error:
#  Accuracy: 92.7%, Avg loss: 0.209286
#
# Test Error:
#  Accuracy: 79.7%, Avg loss: 2.225883
#
# Epoch 99426
# -------------------------------
# Training Error:
#  Accuracy: 93.1%, Avg loss: 0.195908
#
# Test Error:
#  Accuracy: 78.0%, Avg loss: 2.322676
#
# Epoch 99427
# -------------------------------
# Training Error:
#  Accuracy: 93.0%, Avg loss: 0.207546
#
# Test Error:
#  Accuracy: 78.7%, Avg loss: 2.049872
#
# Epoch 99428
# -------------------------------
# Training Error:
#  Accuracy: 93.6%, Avg loss: 0.193066
#
# Test Error:
#  Accuracy: 78.3%, Avg loss: 2.228247
#
# Epoch 99429
# -------------------------------
# Training Error:
#  Accuracy: 93.6%, Avg loss: 0.199091
#
# Test Error:
#  Accuracy: 78.3%, Avg loss: 2.240742
#
# Epoch 99430
# -------------------------------
# Training Error:
#  Accuracy: 92.3%, Avg loss: 0.223071
#
# Test Error:
#  Accuracy: 78.3%, Avg loss: 2.261887
#
# Epoch 99431
# -------------------------------
# Training Error:
#  Accuracy: 94.1%, Avg loss: 0.220682
#
# Test Error:
#  Accuracy: 78.7%, Avg loss: 2.220617
#
# Epoch 99432
# -------------------------------
# Training Error:
#  Accuracy: 93.1%, Avg loss: 0.201751
#
# Test Error:
#  Accuracy: 78.3%, Avg loss: 2.215873
#
# Epoch 99433
# -------------------------------
# Training Error:
#  Accuracy: 94.1%, Avg loss: 0.194038
#
# Test Error:
#  Accuracy: 78.7%, Avg loss: 2.064832
#
# Epoch 99434
# -------------------------------
# Training Error:
#  Accuracy: 91.9%, Avg loss: 0.239178
#
# Test Error:
#  Accuracy: 77.7%, Avg loss: 2.186775
#
# Epoch 99435
# -------------------------------
# Training Error:
#  Accuracy: 92.9%, Avg loss: 0.224772
#
# Test Error:
#  Accuracy: 81.0%, Avg loss: 2.112131
#
# Epoch 99436
# -------------------------------
# Training Error:
#  Accuracy: 93.3%, Avg loss: 0.202843
#
# Test Error:
#  Accuracy: 75.7%, Avg loss: 2.200946
#
# Epoch 99437
# -------------------------------
# Training Error:
#  Accuracy: 93.0%, Avg loss: 0.205474
#
# Test Error:
#  Accuracy: 79.3%, Avg loss: 2.142476
#
# Epoch 99438
# -------------------------------
# Training Error:
#  Accuracy: 93.3%, Avg loss: 0.186184
#
# Test Error:
#  Accuracy: 78.0%, Avg loss: 2.211102
#
# Epoch 99439
# -------------------------------
# Training Error:
#  Accuracy: 93.9%, Avg loss: 0.190916
#
# Test Error:
#  Accuracy: 80.0%, Avg loss: 2.172277
#
# Epoch 99440
# -------------------------------
# Training Error:
#  Accuracy: 94.3%, Avg loss: 0.184429
#
# Test Error:
#  Accuracy: 78.7%, Avg loss: 2.126846
#
# Epoch 99441
# -------------------------------
# Training Error:
#  Accuracy: 94.3%, Avg loss: 0.194325
#
# Test Error:
#  Accuracy: 79.3%, Avg loss: 2.223752
#
# Epoch 99442
# -------------------------------
# Training Error:
#  Accuracy: 94.7%, Avg loss: 0.175174
#
# Test Error:
#  Accuracy: 79.3%, Avg loss: 2.278441
#
# Epoch 99443
# -------------------------------
# Training Error:
#  Accuracy: 93.7%, Avg loss: 0.180300
#
# Test Error:
#  Accuracy: 78.3%, Avg loss: 2.090369
#
# Epoch 99444
# -------------------------------
# Training Error:
#  Accuracy: 94.6%, Avg loss: 0.173434
#
# Test Error:
#  Accuracy: 80.0%, Avg loss: 2.169340
#
# Epoch 99445
# -------------------------------
# Training Error:
#  Accuracy: 94.1%, Avg loss: 0.179983
#
# Test Error:
#  Accuracy: 79.3%, Avg loss: 2.169426
#
# Epoch 99446
# -------------------------------
# Training Error:
#  Accuracy: 94.4%, Avg loss: 0.207684
#
# Test Error:
#  Accuracy: 78.0%, Avg loss: 2.176306
#
# Epoch 99447
# -------------------------------
# Training Error:
#  Accuracy: 94.3%, Avg loss: 0.224638
#
# Test Error:
#  Accuracy: 79.3%, Avg loss: 2.193992
#
# Epoch 99448
# -------------------------------
# Training Error:
#  Accuracy: 93.9%, Avg loss: 0.185274
#
# Test Error:
#  Accuracy: 78.3%, Avg loss: 2.089182
#
# Epoch 99449
# -------------------------------
# Training Error:
#  Accuracy: 94.6%, Avg loss: 0.180555
#
# Test Error:
#  Accuracy: 79.7%, Avg loss: 2.072554
#
# Epoch 99450
# -------------------------------
# Training Error:
#  Accuracy: 93.6%, Avg loss: 0.193862
#
# Test Error:
#  Accuracy: 78.3%, Avg loss: 2.175232
#
# Epoch 99451
# -------------------------------
# Training Error:
#  Accuracy: 94.0%, Avg loss: 0.228951
#
# Test Error:
#  Accuracy: 80.0%, Avg loss: 2.139931
#
# Epoch 99452
# -------------------------------
# Training Error:
#  Accuracy: 93.6%, Avg loss: 0.192183
#
# Test Error:
#  Accuracy: 79.3%, Avg loss: 2.156168
#
# Epoch 99453
# -------------------------------
# Training Error:
#  Accuracy: 93.4%, Avg loss: 0.203891
#
# Test Error:
#  Accuracy: 79.3%, Avg loss: 2.142629
#
# Epoch 99454
# -------------------------------
# Training Error:
#  Accuracy: 94.1%, Avg loss: 0.209157
#
# Test Error:
#  Accuracy: 78.7%, Avg loss: 2.138071
#
# Epoch 99455
# -------------------------------
# Training Error:
#  Accuracy: 93.9%, Avg loss: 0.206175
#
# Test Error:
#  Accuracy: 80.3%, Avg loss: 2.075387
#
# Epoch 99456
# -------------------------------
# Training Error:
#  Accuracy: 93.3%, Avg loss: 0.217883
#
# Test Error:
#  Accuracy: 78.7%, Avg loss: 2.233469
#
# Epoch 99457
# -------------------------------
# Training Error:
#  Accuracy: 94.1%, Avg loss: 0.187392
#
# Test Error:
#  Accuracy: 79.3%, Avg loss: 2.237945
#
# Epoch 99458
# -------------------------------
# Training Error:
#  Accuracy: 93.7%, Avg loss: 0.191916
#
# Test Error:
#  Accuracy: 78.3%, Avg loss: 2.028852
#
# Epoch 99459
# -------------------------------
# Training Error:
#  Accuracy: 94.0%, Avg loss: 0.203002
#
# Test Error:
#  Accuracy: 79.0%, Avg loss: 2.150277
#
# Epoch 99460
# -------------------------------
# Training Error:
#  Accuracy: 93.4%, Avg loss: 0.212058
#
# Test Error:
#  Accuracy: 79.0%, Avg loss: 2.153412
#
# Epoch 99461
# -------------------------------
# Training Error:
#  Accuracy: 94.1%, Avg loss: 0.198174
#
# Test Error:
#  Accuracy: 79.3%, Avg loss: 2.164810
#
# Epoch 99462
# -------------------------------
# Training Error:
#  Accuracy: 93.4%, Avg loss: 0.196088
#
# Test Error:
#  Accuracy: 79.0%, Avg loss: 2.145938
#
# Epoch 99463
# -------------------------------
# Training Error:
#  Accuracy: 93.6%, Avg loss: 0.235176
#
# Test Error:
#  Accuracy: 80.0%, Avg loss: 2.193361
#
# Epoch 99464
# -------------------------------
# Training Error:
#  Accuracy: 92.9%, Avg loss: 0.207159
#
# Test Error:
#  Accuracy: 77.7%, Avg loss: 2.261648
#
# Epoch 99465
# -------------------------------
# Training Error:
#  Accuracy: 93.3%, Avg loss: 0.215495
#
# Test Error:
#  Accuracy: 78.7%, Avg loss: 2.252632
#
# Epoch 99466
# -------------------------------
# Training Error:
#  Accuracy: 92.3%, Avg loss: 0.241441
#
# Test Error:
#  Accuracy: 79.0%, Avg loss: 2.216903
#
# Epoch 99467
# -------------------------------
# Training Error:
#  Accuracy: 92.7%, Avg loss: 0.228614
#
# Test Error:
#  Accuracy: 77.0%, Avg loss: 2.268050
#
# Epoch 99468
# -------------------------------
# Training Error:
#  Accuracy: 92.9%, Avg loss: 0.205105
#
# Test Error:
#  Accuracy: 79.3%, Avg loss: 2.346307
#
# Epoch 99469
# -------------------------------
# Training Error:
#  Accuracy: 93.4%, Avg loss: 0.252805
#
# Test Error:
#  Accuracy: 77.3%, Avg loss: 2.014946
#
# Epoch 99470
# -------------------------------
# Training Error:
#  Accuracy: 93.0%, Avg loss: 0.212703
#
# Test Error:
#  Accuracy: 78.0%, Avg loss: 2.301722
#
# Epoch 99471
# -------------------------------
# Training Error:
#  Accuracy: 92.9%, Avg loss: 0.257538
#
# Test Error:
#  Accuracy: 78.7%, Avg loss: 2.209483
#
# Epoch 99472
# -------------------------------
# Training Error:
#  Accuracy: 92.1%, Avg loss: 0.223892
#
# Test Error:
#  Accuracy: 76.7%, Avg loss: 2.212156
#
# Epoch 99473
# -------------------------------
# Training Error:
#  Accuracy: 92.9%, Avg loss: 0.228669
#
# Test Error:
#  Accuracy: 80.3%, Avg loss: 2.219087
#
# Epoch 99474
# -------------------------------
# Training Error:
#  Accuracy: 93.3%, Avg loss: 0.222177
#
# Test Error:
#  Accuracy: 79.3%, Avg loss: 2.257989
#
# Epoch 99475
# -------------------------------
# Training Error:
#  Accuracy: 93.9%, Avg loss: 0.197224
#
# Test Error:
#  Accuracy: 77.7%, Avg loss: 2.100297
#
# Epoch 99476
# -------------------------------
# Training Error:
#  Accuracy: 93.9%, Avg loss: 0.187598
#
# Test Error:
#  Accuracy: 76.3%, Avg loss: 2.192001
#
# Epoch 99477
# -------------------------------
# Training Error:
#  Accuracy: 93.1%, Avg loss: 0.228032
#
# Test Error:
#  Accuracy: 78.3%, Avg loss: 2.203281
#
# Epoch 99478
# -------------------------------
# Training Error:
#  Accuracy: 92.9%, Avg loss: 0.208290
#
# Test Error:
#  Accuracy: 75.0%, Avg loss: 2.231544
#
# Epoch 99479
# -------------------------------
# Training Error:
#  Accuracy: 93.9%, Avg loss: 0.205903
#
# Test Error:
#  Accuracy: 80.0%, Avg loss: 2.138265
#
# Epoch 99480
# -------------------------------
# Training Error:
#  Accuracy: 93.6%, Avg loss: 0.190073
#
# Test Error:
#  Accuracy: 76.7%, Avg loss: 2.205069
#
# Epoch 99481
# -------------------------------
# Training Error:
#  Accuracy: 93.4%, Avg loss: 0.207445
#
# Test Error:
#  Accuracy: 80.7%, Avg loss: 2.029156
#
# Epoch 99482
# -------------------------------
# Training Error:
#  Accuracy: 93.9%, Avg loss: 0.176746
#
# Test Error:
#  Accuracy: 78.0%, Avg loss: 2.032373
#
# Epoch 99483
# -------------------------------
# Training Error:
#  Accuracy: 94.0%, Avg loss: 0.190670
#
# Test Error:
#  Accuracy: 78.7%, Avg loss: 2.128975
#
# Epoch 99484
# -------------------------------
# Training Error:
#  Accuracy: 94.1%, Avg loss: 0.176747
#
# Test Error:
#  Accuracy: 79.0%, Avg loss: 2.071129
#
# Epoch 99485
# -------------------------------
# Training Error:
#  Accuracy: 93.7%, Avg loss: 0.198125
#
# Test Error:
#  Accuracy: 78.7%, Avg loss: 2.188781
#
# Epoch 99486
# -------------------------------
# Training Error:
#  Accuracy: 93.1%, Avg loss: 0.212902
#
# Test Error:
#  Accuracy: 78.0%, Avg loss: 2.249476
#
# Epoch 99487
# -------------------------------
# Training Error:
#  Accuracy: 93.6%, Avg loss: 0.224018
#
# Test Error:
#  Accuracy: 79.7%, Avg loss: 2.086843
#
# Epoch 99488
# -------------------------------
# Training Error:
#  Accuracy: 92.4%, Avg loss: 0.221766
#
# Test Error:
#  Accuracy: 78.7%, Avg loss: 2.104302
#
# Epoch 99489
# -------------------------------
# Training Error:
#  Accuracy: 92.3%, Avg loss: 0.231799
#
# Test Error:
#  Accuracy: 80.0%, Avg loss: 1.954145
#
# Epoch 99490
# -------------------------------
# Training Error:
#  Accuracy: 93.3%, Avg loss: 0.199576
#
# Test Error:
#  Accuracy: 77.3%, Avg loss: 2.108953
#
# Epoch 99491
# -------------------------------
# Training Error:
#  Accuracy: 91.9%, Avg loss: 0.254127
#
# Test Error:
#  Accuracy: 77.7%, Avg loss: 2.140948
#
# Epoch 99492
# -------------------------------
# Training Error:
#  Accuracy: 92.1%, Avg loss: 0.225217
#
# Test Error:
#  Accuracy: 79.7%, Avg loss: 2.103449
#
# Epoch 99493
# -------------------------------
# Training Error:
#  Accuracy: 91.6%, Avg loss: 0.255003
#
# Test Error:
#  Accuracy: 77.0%, Avg loss: 1.954406
#
# Epoch 99494
# -------------------------------
# Training Error:
#  Accuracy: 92.0%, Avg loss: 0.235453
#
# Test Error:
#  Accuracy: 77.7%, Avg loss: 1.921425
#
# Epoch 99495
# -------------------------------
# Training Error:
#  Accuracy: 93.0%, Avg loss: 0.231235
#
# Test Error:
#  Accuracy: 76.7%, Avg loss: 2.090267
#
# Epoch 99496
# -------------------------------
# Training Error:
#  Accuracy: 92.6%, Avg loss: 0.328929
#
# Test Error:
#  Accuracy: 75.3%, Avg loss: 2.050372
#
# Epoch 99497
# -------------------------------
# Training Error:
#  Accuracy: 91.9%, Avg loss: 0.250861
#
# Test Error:
#  Accuracy: 78.3%, Avg loss: 1.999998
#
# Epoch 99498
# -------------------------------
# Training Error:
#  Accuracy: 92.6%, Avg loss: 0.225367
#
# Test Error:
#  Accuracy: 75.3%, Avg loss: 1.912532
#
# Epoch 99499
# -------------------------------
# Training Error:
#  Accuracy: 92.1%, Avg loss: 0.202219
#
# Test Error:
#  Accuracy: 79.0%, Avg loss: 1.961812
#
# Epoch 99500
# -------------------------------
# Training Error:
#  Accuracy: 93.3%, Avg loss: 0.213897
#
# Test Error:
#  Accuracy: 80.7%, Avg loss: 1.879176
#
# Epoch 99501
# -------------------------------
# Training Error:
#  Accuracy: 93.6%, Avg loss: 0.215155
#
# Test Error:
#  Accuracy: 77.0%, Avg loss: 2.013602
#
# Epoch 99502
# -------------------------------
# Training Error:
#  Accuracy: 91.9%, Avg loss: 0.220606
#
# Test Error:
#  Accuracy: 78.7%, Avg loss: 1.994832
#
# Epoch 99503
# -------------------------------
# Training Error:
#  Accuracy: 93.6%, Avg loss: 0.218938
#
# Test Error:
#  Accuracy: 78.0%, Avg loss: 2.057856
#
# Epoch 99504
# -------------------------------
# Training Error:
#  Accuracy: 93.1%, Avg loss: 0.212827
#
# Test Error:
#  Accuracy: 79.3%, Avg loss: 1.989349
#
# Epoch 99505
# -------------------------------
# Training Error:
#  Accuracy: 93.3%, Avg loss: 0.206780
#
# Test Error:
#  Accuracy: 77.7%, Avg loss: 2.006275
#
# Epoch 99506
# -------------------------------
# Training Error:
#  Accuracy: 92.9%, Avg loss: 0.234321
#
# Test Error:
#  Accuracy: 80.3%, Avg loss: 1.994779
#
# Epoch 99507
# -------------------------------
# Training Error:
#  Accuracy: 92.0%, Avg loss: 0.217561
#
# Test Error:
#  Accuracy: 77.7%, Avg loss: 2.087956
#
# Epoch 99508
# -------------------------------
# Training Error:
#  Accuracy: 93.1%, Avg loss: 0.202718
#
# Test Error:
#  Accuracy: 78.3%, Avg loss: 2.059440
#
# Epoch 99509
# -------------------------------
# Training Error:
#  Accuracy: 94.3%, Avg loss: 0.215411
#
# Test Error:
#  Accuracy: 79.3%, Avg loss: 2.165668
#
# Epoch 99510
# -------------------------------
# Training Error:
#  Accuracy: 93.3%, Avg loss: 0.225349
#
# Test Error:
#  Accuracy: 76.0%, Avg loss: 2.130264
#
# Epoch 99511
# -------------------------------
# Training Error:
#  Accuracy: 92.9%, Avg loss: 0.220814
#
# Test Error:
#  Accuracy: 80.3%, Avg loss: 2.015102
#
# Epoch 99512
# -------------------------------
# Training Error:
#  Accuracy: 93.0%, Avg loss: 0.220724
#
# Test Error:
#  Accuracy: 76.3%, Avg loss: 2.107163
#
# Epoch 99513
# -------------------------------
# Training Error:
#  Accuracy: 93.3%, Avg loss: 0.236591
#
# Test Error:
#  Accuracy: 79.0%, Avg loss: 2.054012
#
# Epoch 99514
# -------------------------------
# Training Error:
#  Accuracy: 92.6%, Avg loss: 0.311980
#
# Test Error:
#  Accuracy: 78.3%, Avg loss: 1.913456
#
# Epoch 99515
# -------------------------------
# Training Error:
#  Accuracy: 92.6%, Avg loss: 0.219305
#
# Test Error:
#  Accuracy: 78.0%, Avg loss: 1.865922
#
# Epoch 99516
# -------------------------------
# Training Error:
#  Accuracy: 92.4%, Avg loss: 0.240940
#
# Test Error:
#  Accuracy: 80.3%, Avg loss: 1.908320
#
# Epoch 99517
# -------------------------------
# Training Error:
#  Accuracy: 92.7%, Avg loss: 0.244874
#
# Test Error:
#  Accuracy: 77.7%, Avg loss: 2.069221
#
# Epoch 99518
# -------------------------------
# Training Error:
#  Accuracy: 93.6%, Avg loss: 0.199090
#
# Test Error:
#  Accuracy: 79.0%, Avg loss: 2.277031
#
# Epoch 99519
# -------------------------------
# Training Error:
#  Accuracy: 93.7%, Avg loss: 0.209903
#
# Test Error:
#  Accuracy: 78.3%, Avg loss: 1.918885
#
# Epoch 99520
# -------------------------------
# Training Error:
#  Accuracy: 93.0%, Avg loss: 0.217316
#
# Test Error:
#  Accuracy: 77.7%, Avg loss: 1.889692
#
# Epoch 99521
# -------------------------------
# Training Error:
#  Accuracy: 93.0%, Avg loss: 0.205205
#
# Test Error:
#  Accuracy: 79.3%, Avg loss: 1.989731
#
# Epoch 99522
# -------------------------------
# Training Error:
#  Accuracy: 93.6%, Avg loss: 0.207616
#
# Test Error:
#  Accuracy: 77.7%, Avg loss: 2.034138
#
# Epoch 99523
# -------------------------------
# Training Error:
#  Accuracy: 93.3%, Avg loss: 0.217986
#
# Test Error:
#  Accuracy: 78.7%, Avg loss: 2.137107
#
# Epoch 99524
# -------------------------------
# Training Error:
#  Accuracy: 94.3%, Avg loss: 0.189255
#
# Test Error:
#  Accuracy: 79.0%, Avg loss: 2.060341
#
# Epoch 99525
# -------------------------------
# Training Error:
#  Accuracy: 93.9%, Avg loss: 0.197071
#
# Test Error:
#  Accuracy: 77.0%, Avg loss: 2.097065
#
# Epoch 99526
# -------------------------------
# Training Error:
#  Accuracy: 94.6%, Avg loss: 0.202701
#
# Test Error:
#  Accuracy: 79.7%, Avg loss: 1.924756
#
# Epoch 99527
# -------------------------------
# Training Error:
#  Accuracy: 94.4%, Avg loss: 0.184863
#
# Test Error:
#  Accuracy: 78.3%, Avg loss: 2.041379
#
# Epoch 99528
# -------------------------------
# Training Error:
#  Accuracy: 94.0%, Avg loss: 0.215196
#
# Test Error:
#  Accuracy: 79.3%, Avg loss: 2.049309
#
# Epoch 99529
# -------------------------------
# Training Error:
#  Accuracy: 94.4%, Avg loss: 0.203104
#
# Test Error:
#  Accuracy: 78.3%, Avg loss: 2.191843
#
# Epoch 99530
# -------------------------------
# Training Error:
#  Accuracy: 93.7%, Avg loss: 0.202757
#
# Test Error:
#  Accuracy: 77.0%, Avg loss: 2.034305
#
# Epoch 99531
# -------------------------------
# Training Error:
#  Accuracy: 94.0%, Avg loss: 0.210056
#
# Test Error:
#  Accuracy: 79.7%, Avg loss: 2.027895
#
# Epoch 99532
# -------------------------------
# Training Error:
#  Accuracy: 94.1%, Avg loss: 0.216666
#
# Test Error:
#  Accuracy: 76.7%, Avg loss: 2.094140
#
# Epoch 99533
# -------------------------------
# Training Error:
#  Accuracy: 93.6%, Avg loss: 0.208165
#
# Test Error:
#  Accuracy: 78.7%, Avg loss: 1.934003
#
# Epoch 99534
# -------------------------------
# Training Error:
#  Accuracy: 93.9%, Avg loss: 0.219480
#
# Test Error:
#  Accuracy: 78.7%, Avg loss: 2.035043
#
# Epoch 99535
# -------------------------------
# Training Error:
#  Accuracy: 92.9%, Avg loss: 0.206724
#
# Test Error:
#  Accuracy: 77.3%, Avg loss: 2.045509
#
# Epoch 99536
# -------------------------------
# Training Error:
#  Accuracy: 94.1%, Avg loss: 0.196737
#
# Test Error:
#  Accuracy: 79.3%, Avg loss: 2.009331
#
# Epoch 99537
# -------------------------------
# Training Error:
#  Accuracy: 93.7%, Avg loss: 0.194172
#
# Test Error:
#  Accuracy: 76.3%, Avg loss: 2.025168
#
# Epoch 99538
# -------------------------------
# Training Error:
#  Accuracy: 93.6%, Avg loss: 0.205523
#
# Test Error:
#  Accuracy: 76.7%, Avg loss: 2.065257
#
# Epoch 99539
# -------------------------------
# Training Error:
#  Accuracy: 93.4%, Avg loss: 0.212424
#
# Test Error:
#  Accuracy: 78.0%, Avg loss: 2.043663
#
# Epoch 99540
# -------------------------------
# Training Error:
#  Accuracy: 94.3%, Avg loss: 0.196149
#
# Test Error:
#  Accuracy: 77.0%, Avg loss: 2.055880
#
# Epoch 99541
# -------------------------------
# Training Error:
#  Accuracy: 93.4%, Avg loss: 0.243621
#
# Test Error:
#  Accuracy: 79.0%, Avg loss: 2.068974
#
# Epoch 99542
# -------------------------------
# Training Error:
#  Accuracy: 93.3%, Avg loss: 0.210305
#
# Test Error:
#  Accuracy: 77.0%, Avg loss: 2.034930
#
# Epoch 99543
# -------------------------------
# Training Error:
#  Accuracy: 92.7%, Avg loss: 0.213896
#
# Test Error:
#  Accuracy: 78.7%, Avg loss: 2.091124
#
# Epoch 99544
# -------------------------------
# Training Error:
#  Accuracy: 93.7%, Avg loss: 0.223200
#
# Test Error:
#  Accuracy: 76.3%, Avg loss: 2.060099
#
# Epoch 99545
# -------------------------------
# Training Error:
#  Accuracy: 93.9%, Avg loss: 0.203508
#
# Test Error:
#  Accuracy: 78.7%, Avg loss: 2.220649
#
# Epoch 99546
# -------------------------------
# Training Error:
#  Accuracy: 94.0%, Avg loss: 0.195898
#
# Test Error:
#  Accuracy: 76.7%, Avg loss: 2.072642
#
# Epoch 99547
# -------------------------------
# Training Error:
#  Accuracy: 93.4%, Avg loss: 0.210703
#
# Test Error:
#  Accuracy: 77.7%, Avg loss: 2.040616
#
# Epoch 99548
# -------------------------------
# Training Error:
#  Accuracy: 93.4%, Avg loss: 0.208743
#
# Test Error:
#  Accuracy: 79.0%, Avg loss: 2.035660
#
# Epoch 99549
# -------------------------------
# Training Error:
#  Accuracy: 93.6%, Avg loss: 0.201056
#
# Test Error:
#  Accuracy: 76.7%, Avg loss: 1.992714
#
# Epoch 99550
# -------------------------------
# Training Error:
#  Accuracy: 94.9%, Avg loss: 0.186116
#
# Test Error:
#  Accuracy: 75.7%, Avg loss: 2.086149
#
# Epoch 99551
# -------------------------------
# Training Error:
#  Accuracy: 93.6%, Avg loss: 0.191067
#
# Test Error:
#  Accuracy: 77.0%, Avg loss: 2.213496
#
# Epoch 99552
# -------------------------------
# Training Error:
#  Accuracy: 92.9%, Avg loss: 0.205128
#
# Test Error:
#  Accuracy: 78.0%, Avg loss: 2.087742
#
# Epoch 99553
# -------------------------------
# Training Error:
#  Accuracy: 93.7%, Avg loss: 0.202255
#
# Test Error:
#  Accuracy: 76.7%, Avg loss: 2.041635
#
# Epoch 99554
# -------------------------------
# Training Error:
#  Accuracy: 93.6%, Avg loss: 0.193857
#
# Test Error:
#  Accuracy: 79.7%, Avg loss: 2.039884
#
# Epoch 99555
# -------------------------------
# Training Error:
#  Accuracy: 93.4%, Avg loss: 0.223223
#
# Test Error:
#  Accuracy: 78.3%, Avg loss: 2.069750
#
# Epoch 99556
# -------------------------------
# Training Error:
#  Accuracy: 93.9%, Avg loss: 0.203687
#
# Test Error:
#  Accuracy: 78.3%, Avg loss: 2.075330
#
# Epoch 99557
# -------------------------------
# Training Error:
#  Accuracy: 93.3%, Avg loss: 0.240904
#
# Test Error:
#  Accuracy: 78.0%, Avg loss: 2.122703
#
# Epoch 99558
# -------------------------------
# Training Error:
#  Accuracy: 93.4%, Avg loss: 0.205996
#
# Test Error:
#  Accuracy: 78.0%, Avg loss: 2.032830
#
# Epoch 99559
# -------------------------------
# Training Error:
#  Accuracy: 93.3%, Avg loss: 0.194017
#
# Test Error:
#  Accuracy: 78.3%, Avg loss: 2.203632
#
# Epoch 99560
# -------------------------------
# Training Error:
#  Accuracy: 93.0%, Avg loss: 0.190972
#
# Test Error:
#  Accuracy: 77.3%, Avg loss: 2.280718
#
# Epoch 99561
# -------------------------------
# Training Error:
#  Accuracy: 94.1%, Avg loss: 0.202492
#
# Test Error:
#  Accuracy: 76.7%, Avg loss: 2.255334
#
# Epoch 99562
# -------------------------------
# Training Error:
#  Accuracy: 93.4%, Avg loss: 0.241065
#
# Test Error:
#  Accuracy: 76.7%, Avg loss: 2.255467
#
# Epoch 99563
# -------------------------------
# Training Error:
#  Accuracy: 93.0%, Avg loss: 0.190297
#
# Test Error:
#  Accuracy: 78.7%, Avg loss: 2.459417
#
# Epoch 99564
# -------------------------------
# Training Error:
#  Accuracy: 94.0%, Avg loss: 0.185758
#
# Test Error:
#  Accuracy: 77.0%, Avg loss: 2.326506
#
# Epoch 99565
# -------------------------------
# Training Error:
#  Accuracy: 94.0%, Avg loss: 0.184552
#
# Test Error:
#  Accuracy: 79.0%, Avg loss: 2.351111
#
# Epoch 99566
# -------------------------------
# Training Error:
#  Accuracy: 94.3%, Avg loss: 0.200004
#
# Test Error:
#  Accuracy: 77.7%, Avg loss: 2.369890
#
# Epoch 99567
# -------------------------------
# Training Error:
#  Accuracy: 94.1%, Avg loss: 0.196034
#
# Test Error:
#  Accuracy: 77.7%, Avg loss: 2.293055
#
# Epoch 99568
# -------------------------------
# Training Error:
#  Accuracy: 94.4%, Avg loss: 0.183009
#
# Test Error:
#  Accuracy: 79.0%, Avg loss: 2.271540
#
# Epoch 99569
# -------------------------------
# Training Error:
#  Accuracy: 93.7%, Avg loss: 0.190945
#
# Test Error:
#  Accuracy: 78.7%, Avg loss: 2.284084
#
# Epoch 99570
# -------------------------------
# Training Error:
#  Accuracy: 94.9%, Avg loss: 0.181290
#
# Test Error:
#  Accuracy: 79.3%, Avg loss: 2.244046
#
# Epoch 99571
# -------------------------------
# Training Error:
#  Accuracy: 93.3%, Avg loss: 0.204639
#
# Test Error:
#  Accuracy: 78.3%, Avg loss: 2.299145
#
# Epoch 99572
# -------------------------------
# Training Error:
#  Accuracy: 93.3%, Avg loss: 0.188905
#
# Test Error:
#  Accuracy: 79.3%, Avg loss: 2.224188
#
# Epoch 99573
# -------------------------------
# Training Error:
#  Accuracy: 94.3%, Avg loss: 0.177774
#
# Test Error:
#  Accuracy: 79.7%, Avg loss: 2.233827
#
# Epoch 99574
# -------------------------------
# Training Error:
#  Accuracy: 94.3%, Avg loss: 0.185192
#
# Test Error:
#  Accuracy: 78.3%, Avg loss: 2.529700
#
# Epoch 99575
# -------------------------------
# Training Error:
#  Accuracy: 94.3%, Avg loss: 0.205463
#
# Test Error:
#  Accuracy: 79.7%, Avg loss: 2.355758
#
# Epoch 99576
# -------------------------------
# Training Error:
#  Accuracy: 93.7%, Avg loss: 0.190820
#
# Test Error:
#  Accuracy: 76.7%, Avg loss: 2.381803
#
# Epoch 99577
# -------------------------------
# Training Error:
#  Accuracy: 93.1%, Avg loss: 0.201748
#
# Test Error:
#  Accuracy: 79.0%, Avg loss: 2.340313
#
# Epoch 99578
# -------------------------------
# Training Error:
#  Accuracy: 93.6%, Avg loss: 0.234951
#
# Test Error:
#  Accuracy: 77.3%, Avg loss: 2.279241
#
# Epoch 99579
# -------------------------------
# Training Error:
#  Accuracy: 93.4%, Avg loss: 0.216582
#
# Test Error:
#  Accuracy: 77.3%, Avg loss: 2.033578
#
# Epoch 99580
# -------------------------------
# Training Error:
#  Accuracy: 91.6%, Avg loss: 0.214424
#
# Test Error:
#  Accuracy: 78.7%, Avg loss: 2.282780
#
# Epoch 99581
# -------------------------------
# Training Error:
#  Accuracy: 92.3%, Avg loss: 0.216212
#
# Test Error:
#  Accuracy: 79.7%, Avg loss: 2.160770
#
# Epoch 99582
# -------------------------------
# Training Error:
#  Accuracy: 91.1%, Avg loss: 0.212690
#
# Test Error:
#  Accuracy: 76.0%, Avg loss: 2.242817
#
# Epoch 99583
# -------------------------------
# Training Error:
#  Accuracy: 93.1%, Avg loss: 0.221044
#
# Test Error:
#  Accuracy: 80.0%, Avg loss: 2.223795
#
# Epoch 99584
# -------------------------------
# Training Error:
#  Accuracy: 91.6%, Avg loss: 0.250839
#
# Test Error:
#  Accuracy: 77.3%, Avg loss: 2.228037
#
# Epoch 99585
# -------------------------------
# Training Error:
#  Accuracy: 91.7%, Avg loss: 0.298304
#
# Test Error:
#  Accuracy: 76.3%, Avg loss: 2.203640
#
# Epoch 99586
# -------------------------------
# Training Error:
#  Accuracy: 91.9%, Avg loss: 0.255101
#
# Test Error:
#  Accuracy: 79.3%, Avg loss: 2.225031
#
# Epoch 99587
# -------------------------------
# Training Error:
#  Accuracy: 91.7%, Avg loss: 0.302450
#
# Test Error:
#  Accuracy: 75.7%, Avg loss: 2.298936
#
# Epoch 99588
# -------------------------------
# Training Error:
#  Accuracy: 90.9%, Avg loss: 0.326548
#
# Test Error:
#  Accuracy: 79.3%, Avg loss: 2.347822
#
# Epoch 99589
# -------------------------------
# Training Error:
#  Accuracy: 91.6%, Avg loss: 0.265133
#
# Test Error:
#  Accuracy: 77.7%, Avg loss: 2.501575
#
# Epoch 99590
# -------------------------------
# Training Error:
#  Accuracy: 91.7%, Avg loss: 0.263313
#
# Test Error:
#  Accuracy: 77.3%, Avg loss: 2.337673
#
# Epoch 99591
# -------------------------------
# Training Error:
#  Accuracy: 92.6%, Avg loss: 0.212316
#
# Test Error:
#  Accuracy: 77.7%, Avg loss: 2.225363
#
# Epoch 99592
# -------------------------------
# Training Error:
#  Accuracy: 92.7%, Avg loss: 0.238869
#
# Test Error:
#  Accuracy: 77.3%, Avg loss: 2.206060
#
# Epoch 99593
# -------------------------------
# Training Error:
#  Accuracy: 92.1%, Avg loss: 0.201403
#
# Test Error:
#  Accuracy: 79.0%, Avg loss: 2.260719
#
# Epoch 99594
# -------------------------------
# Training Error:
#  Accuracy: 93.1%, Avg loss: 0.229222
#
# Test Error:
#  Accuracy: 74.7%, Avg loss: 2.363202
#
# Epoch 99595
# -------------------------------
# Training Error:
#  Accuracy: 91.7%, Avg loss: 0.224165
#
# Test Error:
#  Accuracy: 79.0%, Avg loss: 2.262530
#
# Epoch 99596
# -------------------------------
# Training Error:
#  Accuracy: 93.7%, Avg loss: 0.207743
#
# Test Error:
#  Accuracy: 77.3%, Avg loss: 2.317088
#
# Epoch 99597
# -------------------------------
# Training Error:
#  Accuracy: 93.3%, Avg loss: 0.188975
#
# Test Error:
#  Accuracy: 79.3%, Avg loss: 2.235072
#
# Epoch 99598
# -------------------------------
# Training Error:
#  Accuracy: 93.9%, Avg loss: 0.181853
#
# Test Error:
#  Accuracy: 78.0%, Avg loss: 2.201409
#
# Epoch 99599
# -------------------------------
# Training Error:
#  Accuracy: 92.4%, Avg loss: 0.202691
#
# Test Error:
#  Accuracy: 76.3%, Avg loss: 2.273202
#
# Epoch 99600
# -------------------------------
# Training Error:
#  Accuracy: 92.9%, Avg loss: 0.223014
#
# Test Error:
#  Accuracy: 78.0%, Avg loss: 2.130729
#
# Epoch 99601
# -------------------------------
# Training Error:
#  Accuracy: 92.9%, Avg loss: 0.220196
#
# Test Error:
#  Accuracy: 76.3%, Avg loss: 2.325350
#
# Epoch 99602
# -------------------------------
# Training Error:
#  Accuracy: 92.6%, Avg loss: 0.211410
#
# Test Error:
#  Accuracy: 80.0%, Avg loss: 2.248372
#
# Epoch 99603
# -------------------------------
# Training Error:
#  Accuracy: 93.3%, Avg loss: 0.198163
#
# Test Error:
#  Accuracy: 78.0%, Avg loss: 2.293849
#
# Epoch 99604
# -------------------------------
# Training Error:
#  Accuracy: 92.1%, Avg loss: 0.245417
#
# Test Error:
#  Accuracy: 75.7%, Avg loss: 2.340837
#
# Epoch 99605
# -------------------------------
# Training Error:
#  Accuracy: 91.6%, Avg loss: 0.237321
#
# Test Error:
#  Accuracy: 80.3%, Avg loss: 2.281775
#
# Epoch 99606
# -------------------------------
# Training Error:
#  Accuracy: 93.6%, Avg loss: 0.222359
#
# Test Error:
#  Accuracy: 77.0%, Avg loss: 2.395684
#
# Epoch 99607
# -------------------------------
# Training Error:
#  Accuracy: 92.4%, Avg loss: 0.221772
#
# Test Error:
#  Accuracy: 78.7%, Avg loss: 2.329136
#
# Epoch 99608
# -------------------------------
# Training Error:
#  Accuracy: 93.9%, Avg loss: 0.215015
#
# Test Error:
#  Accuracy: 79.0%, Avg loss: 2.330976
#
# Epoch 99609
# -------------------------------
# Training Error:
#  Accuracy: 93.7%, Avg loss: 0.195501
#
# Test Error:
#  Accuracy: 76.3%, Avg loss: 2.283304
#
# Epoch 99610
# -------------------------------
# Training Error:
#  Accuracy: 94.4%, Avg loss: 0.191908
#
# Test Error:
#  Accuracy: 78.7%, Avg loss: 2.170833
#
# Epoch 99611
# -------------------------------
# Training Error:
#  Accuracy: 92.3%, Avg loss: 0.244028
#
# Test Error:
#  Accuracy: 77.3%, Avg loss: 2.351397
#
# Epoch 99612
# -------------------------------
# Training Error:
#  Accuracy: 92.7%, Avg loss: 0.218357
#
# Test Error:
#  Accuracy: 80.0%, Avg loss: 2.303515
#
# Epoch 99613
# -------------------------------
# Training Error:
#  Accuracy: 93.6%, Avg loss: 0.210083
#
# Test Error:
#  Accuracy: 78.0%, Avg loss: 2.283919
#
# Epoch 99614
# -------------------------------
# Training Error:
#  Accuracy: 93.1%, Avg loss: 0.224751
#
# Test Error:
#  Accuracy: 77.7%, Avg loss: 2.310080
#
# Epoch 99615
# -------------------------------
# Training Error:
#  Accuracy: 93.9%, Avg loss: 0.193725
#
# Test Error:
#  Accuracy: 78.3%, Avg loss: 2.329604
#
# Epoch 99616
# -------------------------------
# Training Error:
#  Accuracy: 92.7%, Avg loss: 0.240045
#
# Test Error:
#  Accuracy: 76.0%, Avg loss: 2.353631
#
# Epoch 99617
# -------------------------------
# Training Error:
#  Accuracy: 92.4%, Avg loss: 0.211260
#
# Test Error:
#  Accuracy: 79.0%, Avg loss: 2.280565
#
# Epoch 99618
# -------------------------------
# Training Error:
#  Accuracy: 93.4%, Avg loss: 0.207594
#
# Test Error:
#  Accuracy: 76.0%, Avg loss: 2.367009
#
# Epoch 99619
# -------------------------------
# Training Error:
#  Accuracy: 92.0%, Avg loss: 0.238703
#
# Test Error:
#  Accuracy: 77.3%, Avg loss: 2.192851
#
# Epoch 99620
# -------------------------------
# Training Error:
#  Accuracy: 93.6%, Avg loss: 0.214008
#
# Test Error:
#  Accuracy: 79.3%, Avg loss: 2.167282
#
# Epoch 99621
# -------------------------------
# Training Error:
#  Accuracy: 92.7%, Avg loss: 0.217357
#
# Test Error:
#  Accuracy: 75.7%, Avg loss: 2.132738
#
# Epoch 99622
# -------------------------------
# Training Error:
#  Accuracy: 92.6%, Avg loss: 0.205461
#
# Test Error:
#  Accuracy: 79.3%, Avg loss: 2.231683
#
# Epoch 99623
# -------------------------------
# Training Error:
#  Accuracy: 93.9%, Avg loss: 0.216601
#
# Test Error:
#  Accuracy: 75.7%, Avg loss: 2.288802
#
# Epoch 99624
# -------------------------------
# Training Error:
#  Accuracy: 91.9%, Avg loss: 0.220772
#
# Test Error:
#  Accuracy: 76.3%, Avg loss: 2.306582
#
# Epoch 99625
# -------------------------------
# Training Error:
#  Accuracy: 93.3%, Avg loss: 0.237668
#
# Test Error:
#  Accuracy: 78.3%, Avg loss: 2.304870
#
# Epoch 99626
# -------------------------------
# Training Error:
#  Accuracy: 93.6%, Avg loss: 0.210162
#
# Test Error:
#  Accuracy: 76.0%, Avg loss: 2.321995
#
# Epoch 99627
# -------------------------------
# Training Error:
#  Accuracy: 94.4%, Avg loss: 0.189816
#
# Test Error:
#  Accuracy: 77.7%, Avg loss: 2.326616
#
# Epoch 99628
# -------------------------------
# Training Error:
#  Accuracy: 94.9%, Avg loss: 0.217159
#
# Test Error:
#  Accuracy: 77.3%, Avg loss: 2.248110
#
# Epoch 99629
# -------------------------------
# Training Error:
#  Accuracy: 94.3%, Avg loss: 0.192475
#
# Test Error:
#  Accuracy: 79.0%, Avg loss: 2.260160
#
# Epoch 99630
# -------------------------------
# Training Error:
#  Accuracy: 94.4%, Avg loss: 0.200641
#
# Test Error:
#  Accuracy: 76.7%, Avg loss: 2.135930
#
# Epoch 99631
# -------------------------------
# Training Error:
#  Accuracy: 94.1%, Avg loss: 0.208449
#
# Test Error:
#  Accuracy: 78.0%, Avg loss: 2.277909
#
# Epoch 99632
# -------------------------------
# Training Error:
#  Accuracy: 92.9%, Avg loss: 0.241684
#
# Test Error:
#  Accuracy: 78.3%, Avg loss: 2.236555
#
# Epoch 99633
# -------------------------------
# Training Error:
#  Accuracy: 93.9%, Avg loss: 0.191616
#
# Test Error:
#  Accuracy: 77.3%, Avg loss: 2.251058
#
# Epoch 99634
# -------------------------------
# Training Error:
#  Accuracy: 93.9%, Avg loss: 0.213939
#
# Test Error:
#  Accuracy: 78.3%, Avg loss: 2.214514
#
# Epoch 99635
# -------------------------------
# Training Error:
#  Accuracy: 93.9%, Avg loss: 0.234570
#
# Test Error:
#  Accuracy: 77.7%, Avg loss: 2.179650
#
# Epoch 99636
# -------------------------------
# Training Error:
#  Accuracy: 93.4%, Avg loss: 0.195769
#
# Test Error:
#  Accuracy: 77.3%, Avg loss: 2.206408
#
# Epoch 99637
# -------------------------------
# Training Error:
#  Accuracy: 94.0%, Avg loss: 0.204469
#
# Test Error:
#  Accuracy: 76.7%, Avg loss: 2.286641
#
# Epoch 99638
# -------------------------------
# Training Error:
#  Accuracy: 93.6%, Avg loss: 0.201232
#
# Test Error:
#  Accuracy: 76.0%, Avg loss: 2.174028
#
# Epoch 99639
# -------------------------------
# Training Error:
#  Accuracy: 93.9%, Avg loss: 0.190057
#
# Test Error:
#  Accuracy: 77.7%, Avg loss: 2.228369
#
# Epoch 99640
# -------------------------------
# Training Error:
#  Accuracy: 94.3%, Avg loss: 0.205304
#
# Test Error:
#  Accuracy: 78.0%, Avg loss: 2.229461
#
# Epoch 99641
# -------------------------------
# Training Error:
#  Accuracy: 93.7%, Avg loss: 0.193378
#
# Test Error:
#  Accuracy: 79.7%, Avg loss: 2.175109
#
# Epoch 99642
# -------------------------------
# Training Error:
#  Accuracy: 93.9%, Avg loss: 0.204625
#
# Test Error:
#  Accuracy: 77.7%, Avg loss: 2.165994
#
# Epoch 99643
# -------------------------------
# Training Error:
#  Accuracy: 93.9%, Avg loss: 0.205301
#
# Test Error:
#  Accuracy: 78.3%, Avg loss: 2.174831
#
# Epoch 99644
# -------------------------------
# Training Error:
#  Accuracy: 94.7%, Avg loss: 0.185266
#
# Test Error:
#  Accuracy: 78.3%, Avg loss: 2.082210
#
# Epoch 99645
# -------------------------------
# Training Error:
#  Accuracy: 94.7%, Avg loss: 0.191020
#
# Test Error:
#  Accuracy: 79.7%, Avg loss: 2.243915
#
# Epoch 99646
# -------------------------------
# Training Error:
#  Accuracy: 94.7%, Avg loss: 0.178668
#
# Test Error:
#  Accuracy: 77.0%, Avg loss: 2.220086
#
# Epoch 99647
# -------------------------------
# Training Error:
#  Accuracy: 93.4%, Avg loss: 0.199333
#
# Test Error:
#  Accuracy: 78.0%, Avg loss: 2.137750
#
# Epoch 99648
# -------------------------------
# Training Error:
#  Accuracy: 93.4%, Avg loss: 0.199704
#
# Test Error:
#  Accuracy: 79.3%, Avg loss: 2.157891
#
# Epoch 99649
# -------------------------------
# Training Error:
#  Accuracy: 93.4%, Avg loss: 0.234758
#
# Test Error:
#  Accuracy: 78.0%, Avg loss: 2.111625
#
# Epoch 99650
# -------------------------------
# Training Error:
#  Accuracy: 92.3%, Avg loss: 0.230784
#
# Test Error:
#  Accuracy: 79.3%, Avg loss: 2.087523
#
# Epoch 99651
# -------------------------------
# Training Error:
#  Accuracy: 93.9%, Avg loss: 0.187588
#
# Test Error:
#  Accuracy: 78.7%, Avg loss: 2.106802
#
# Epoch 99652
# -------------------------------
# Training Error:
#  Accuracy: 93.7%, Avg loss: 0.233101
#
# Test Error:
#  Accuracy: 79.0%, Avg loss: 2.172610
#
# Epoch 99653
# -------------------------------
# Training Error:
#  Accuracy: 94.3%, Avg loss: 0.197183
#
# Test Error:
#  Accuracy: 78.3%, Avg loss: 2.261252
#
# Epoch 99654
# -------------------------------
# Training Error:
#  Accuracy: 92.9%, Avg loss: 0.212060
#
# Test Error:
#  Accuracy: 77.7%, Avg loss: 2.177548
#
# Epoch 99655
# -------------------------------
# Training Error:
#  Accuracy: 92.9%, Avg loss: 0.211651
#
# Test Error:
#  Accuracy: 78.3%, Avg loss: 2.163323
#
# Epoch 99656
# -------------------------------
# Training Error:
#  Accuracy: 93.4%, Avg loss: 0.208396
#
# Test Error:
#  Accuracy: 76.7%, Avg loss: 2.170341
#
# Epoch 99657
# -------------------------------
# Training Error:
#  Accuracy: 93.4%, Avg loss: 0.207555
#
# Test Error:
#  Accuracy: 79.0%, Avg loss: 2.169354
#
# Epoch 99658
# -------------------------------
# Training Error:
#  Accuracy: 93.9%, Avg loss: 0.185698
#
# Test Error:
#  Accuracy: 77.7%, Avg loss: 2.246947
#
# Epoch 99659
# -------------------------------
# Training Error:
#  Accuracy: 92.7%, Avg loss: 0.256146
#
# Test Error:
#  Accuracy: 78.0%, Avg loss: 2.219853
#
# Epoch 99660
# -------------------------------
# Training Error:
#  Accuracy: 93.6%, Avg loss: 0.206562
#
# Test Error:
#  Accuracy: 78.0%, Avg loss: 2.123377
#
# Epoch 99661
# -------------------------------
# Training Error:
#  Accuracy: 93.1%, Avg loss: 0.225539
#
# Test Error:
#  Accuracy: 77.7%, Avg loss: 2.315441
#
# Epoch 99662
# -------------------------------
# Training Error:
#  Accuracy: 93.7%, Avg loss: 0.192904
#
# Test Error:
#  Accuracy: 78.7%, Avg loss: 2.054421
#
# Epoch 99663
# -------------------------------
# Training Error:
#  Accuracy: 92.7%, Avg loss: 0.242607
#
# Test Error:
#  Accuracy: 78.3%, Avg loss: 2.137883
#
# Epoch 99664
# -------------------------------
# Training Error:
#  Accuracy: 92.9%, Avg loss: 0.206461
#
# Test Error:
#  Accuracy: 78.3%, Avg loss: 2.133534
#
# Epoch 99665
# -------------------------------
# Training Error:
#  Accuracy: 92.9%, Avg loss: 0.218432
#
# Test Error:
#  Accuracy: 79.3%, Avg loss: 2.042678
#
# Epoch 99666
# -------------------------------
# Training Error:
#  Accuracy: 92.7%, Avg loss: 0.203070
#
# Test Error:
#  Accuracy: 75.7%, Avg loss: 1.965413
#
# Epoch 99667
# -------------------------------
# Training Error:
#  Accuracy: 94.0%, Avg loss: 0.212757
#
# Test Error:
#  Accuracy: 79.3%, Avg loss: 2.150712
#
# Epoch 99668
# -------------------------------
# Training Error:
#  Accuracy: 93.0%, Avg loss: 0.327161
#
# Test Error:
#  Accuracy: 77.3%, Avg loss: 2.065644
#
# Epoch 99669
# -------------------------------
# Training Error:
#  Accuracy: 94.9%, Avg loss: 0.190693
#
# Test Error:
#  Accuracy: 79.0%, Avg loss: 2.063201
#
# Epoch 99670
# -------------------------------
# Training Error:
#  Accuracy: 94.0%, Avg loss: 0.228421
#
# Test Error:
#  Accuracy: 78.7%, Avg loss: 2.006154
#
# Epoch 99671
# -------------------------------
# Training Error:
#  Accuracy: 93.1%, Avg loss: 0.201753
#
# Test Error:
#  Accuracy: 77.3%, Avg loss: 1.994841
#
# Epoch 99672
# -------------------------------
# Training Error:
#  Accuracy: 94.1%, Avg loss: 0.192353
#
# Test Error:
#  Accuracy: 77.3%, Avg loss: 1.986519
#
# Epoch 99673
# -------------------------------
# Training Error:
#  Accuracy: 94.0%, Avg loss: 0.195126
#
# Test Error:
#  Accuracy: 78.7%, Avg loss: 2.026990
#
# Epoch 99674
# -------------------------------
# Training Error:
#  Accuracy: 93.7%, Avg loss: 0.191798
#
# Test Error:
#  Accuracy: 78.0%, Avg loss: 2.070851
#
# Epoch 99675
# -------------------------------
# Training Error:
#  Accuracy: 94.0%, Avg loss: 0.188889
#
# Test Error:
#  Accuracy: 78.7%, Avg loss: 2.009972
#
# Epoch 99676
# -------------------------------
# Training Error:
#  Accuracy: 92.1%, Avg loss: 0.239955
#
# Test Error:
#  Accuracy: 74.7%, Avg loss: 2.333199
#
# Epoch 99677
# -------------------------------
# Training Error:
#  Accuracy: 93.0%, Avg loss: 0.217930
#
# Test Error:
#  Accuracy: 79.0%, Avg loss: 2.228428
#
# Epoch 99678
# -------------------------------
# Training Error:
#  Accuracy: 92.7%, Avg loss: 0.207043
#
# Test Error:
#  Accuracy: 78.7%, Avg loss: 2.238603
#
# Epoch 99679
# -------------------------------
# Training Error:
#  Accuracy: 92.0%, Avg loss: 0.225949
#
# Test Error:
#  Accuracy: 79.0%, Avg loss: 2.239368
#
# Epoch 99680
# -------------------------------
# Training Error:
#  Accuracy: 93.0%, Avg loss: 0.229134
#
# Test Error:
#  Accuracy: 79.0%, Avg loss: 2.234594
#
# Epoch 99681
# -------------------------------
# Training Error:
#  Accuracy: 92.9%, Avg loss: 0.220131
#
# Test Error:
#  Accuracy: 78.3%, Avg loss: 2.256279
#
# Epoch 99682
# -------------------------------
# Training Error:
#  Accuracy: 93.1%, Avg loss: 0.231188
#
# Test Error:
#  Accuracy: 78.7%, Avg loss: 2.249685
#
# Epoch 99683
# -------------------------------
# Training Error:
#  Accuracy: 93.0%, Avg loss: 0.214738
#
# Test Error:
#  Accuracy: 78.0%, Avg loss: 2.194480
#
# Epoch 99684
# -------------------------------
# Training Error:
#  Accuracy: 93.0%, Avg loss: 0.215576
#
# Test Error:
#  Accuracy: 79.0%, Avg loss: 2.223525
#
# Epoch 99685
# -------------------------------
# Training Error:
#  Accuracy: 92.9%, Avg loss: 0.240304
#
# Test Error:
#  Accuracy: 78.0%, Avg loss: 2.226538
#
# Epoch 99686
# -------------------------------
# Training Error:
#  Accuracy: 91.9%, Avg loss: 0.255072
#
# Test Error:
#  Accuracy: 79.3%, Avg loss: 2.045004
#
# Epoch 99687
# -------------------------------
# Training Error:
#  Accuracy: 91.1%, Avg loss: 0.306815
#
# Test Error:
#  Accuracy: 75.0%, Avg loss: 2.292126
#
# Epoch 99688
# -------------------------------
# Training Error:
#  Accuracy: 90.1%, Avg loss: 0.370972
#
# Test Error:
#  Accuracy: 79.3%, Avg loss: 2.321924
#
# Epoch 99689
# -------------------------------
# Training Error:
#  Accuracy: 91.7%, Avg loss: 0.283915
#
# Test Error:
#  Accuracy: 75.7%, Avg loss: 2.370236
#
# Epoch 99690
# -------------------------------
# Training Error:
#  Accuracy: 92.1%, Avg loss: 0.269479
#
# Test Error:
#  Accuracy: 78.0%, Avg loss: 2.001615
#
# Epoch 99691
# -------------------------------
# Training Error:
# ...
#
# Epoch 99896
# -------------------------------
# Training Error:
#  Accuracy: 93.7%, Avg loss: 0.214025
#
# Test Error:
#  Accuracy: 75.0%, Avg loss: 2.179468
#
# Epoch 99897
# -------------------------------
# Training Error:
#  Accuracy: 93.3%, Avg loss: 0.238489
#
# Test Error:
#  Accuracy: 76.3%, Avg loss: 2.330629
#
# Epoch 99898
# -------------------------------
# Training Error:
#  Accuracy: 92.0%, Avg loss: 0.287841
#
# Test Error:
#  Accuracy: 78.0%, Avg loss: 2.269495
#
# Epoch 99899
# -------------------------------
# Training Error:
#  Accuracy: 93.6%, Avg loss: 0.208864
#
# Test Error:
#  Accuracy: 81.0%, Avg loss: 2.378304
#
# Epoch 99900
# -------------------------------
# Training Error:
#  Accuracy: 93.1%, Avg loss: 0.203679
#
# Test Error:
#  Accuracy: 77.0%, Avg loss: 2.372250
#
# Epoch 99901
# -------------------------------
# Training Error:
#  Accuracy: 93.9%, Avg loss: 0.192903
#
# Test Error:
#  Accuracy: 79.0%, Avg loss: 2.227025
#
# Epoch 99902
# -------------------------------
# Training Error:
#  Accuracy: 93.7%, Avg loss: 0.226755
#
# Test Error:
#  Accuracy: 77.0%, Avg loss: 2.208567
#
# Epoch 99903
# -------------------------------
# Training Error:
#  Accuracy: 93.0%, Avg loss: 0.214166
#
# Test Error:
#  Accuracy: 78.3%, Avg loss: 2.242619
#
# Epoch 99904
# -------------------------------
# Training Error:
#  Accuracy: 93.4%, Avg loss: 0.226369
#
# Test Error:
#  Accuracy: 78.7%, Avg loss: 2.050048
#
# Epoch 99905
# -------------------------------
# Training Error:
#  Accuracy: 93.6%, Avg loss: 0.224934
#
# Test Error:
#  Accuracy: 80.0%, Avg loss: 2.133700
#
# Epoch 99906
# -------------------------------
# Training Error:
#  Accuracy: 92.6%, Avg loss: 0.198131
#
# Test Error:
#  Accuracy: 78.0%, Avg loss: 2.421014
#
# Epoch 99907
# -------------------------------
# Training Error:
#  Accuracy: 92.7%, Avg loss: 0.222062
#
# Test Error:
#  Accuracy: 77.0%, Avg loss: 2.393437
#
# Epoch 99908
# -------------------------------
# Training Error:
#  Accuracy: 93.4%, Avg loss: 0.204559
#
# Test Error:
#  Accuracy: 76.7%, Avg loss: 2.378492
#
# Epoch 99909
# -------------------------------
# Training Error:
#  Accuracy: 92.9%, Avg loss: 0.224660
#
# Test Error:
#  Accuracy: 77.0%, Avg loss: 2.370152
#
# Epoch 99910
# -------------------------------
# Training Error:
#  Accuracy: 93.0%, Avg loss: 0.241067
#
# Test Error:
#  Accuracy: 79.0%, Avg loss: 2.238444
#
# Epoch 99911
# -------------------------------
# Training Error:
#  Accuracy: 93.1%, Avg loss: 0.244204
#
# Test Error:
#  Accuracy: 75.7%, Avg loss: 2.233190
#
# Epoch 99912
# -------------------------------
# Training Error:
#  Accuracy: 92.4%, Avg loss: 0.311915
#
# Test Error:
#  Accuracy: 75.7%, Avg loss: 2.059902
#
# Epoch 99913
# -------------------------------
# Training Error:
#  Accuracy: 92.6%, Avg loss: 0.241733
#
# Test Error:
#  Accuracy: 80.3%, Avg loss: 2.141919
#
# Epoch 99914
# -------------------------------
# Training Error:
#  Accuracy: 92.1%, Avg loss: 0.278947
#
# Test Error:
#  Accuracy: 77.7%, Avg loss: 2.272992
#
# Epoch 99915
# -------------------------------
# Training Error:
#  Accuracy: 93.0%, Avg loss: 0.216582
#
# Test Error:
#  Accuracy: 79.3%, Avg loss: 2.234756
#
# Epoch 99916
# -------------------------------
# Training Error:
#  Accuracy: 93.7%, Avg loss: 0.221809
#
# Test Error:
#  Accuracy: 77.7%, Avg loss: 2.154310
#
# Epoch 99917
# -------------------------------
# Training Error:
#  Accuracy: 93.3%, Avg loss: 0.205580
#
# Test Error:
#  Accuracy: 76.3%, Avg loss: 2.067762
#
# Epoch 99918
# -------------------------------
# Training Error:
#  Accuracy: 92.0%, Avg loss: 0.231820
#
# Test Error:
#  Accuracy: 79.7%, Avg loss: 1.909056
#
# Epoch 99919
# -------------------------------
# Training Error:
#  Accuracy: 93.6%, Avg loss: 0.200795
#
# Test Error:
#  Accuracy: 76.0%, Avg loss: 2.178390
#
# Epoch 99920
# -------------------------------
# Training Error:
#  Accuracy: 93.3%, Avg loss: 0.209067
#
# Test Error:
#  Accuracy: 77.7%, Avg loss: 2.240262
#
# Epoch 99921
# -------------------------------
# Training Error:
#  Accuracy: 93.0%, Avg loss: 0.239394
#
# Test Error:
#  Accuracy: 76.7%, Avg loss: 2.331234
#
# Epoch 99922
# -------------------------------
# Training Error:
#  Accuracy: 92.4%, Avg loss: 0.254082
#
# Test Error:
#  Accuracy: 78.3%, Avg loss: 2.194169
#
# Epoch 99923
# -------------------------------
# Training Error:
#  Accuracy: 93.4%, Avg loss: 0.213195
#
# Test Error:
#  Accuracy: 78.0%, Avg loss: 2.421268
#
# Epoch 99924
# -------------------------------
# Training Error:
#  Accuracy: 92.6%, Avg loss: 0.228155
#
# Test Error:
#  Accuracy: 76.0%, Avg loss: 2.403522
#
# Epoch 99925
# -------------------------------
# Training Error:
#  Accuracy: 92.7%, Avg loss: 0.222226
#
# Test Error:
#  Accuracy: 79.0%, Avg loss: 2.318882
#
# Epoch 99926
# -------------------------------
# Training Error:
#  Accuracy: 93.0%, Avg loss: 0.223674
#
# Test Error:
#  Accuracy: 76.7%, Avg loss: 2.311342
#
# Epoch 99927
# -------------------------------
# Training Error:
#  Accuracy: 93.1%, Avg loss: 0.218475
#
# Test Error:
#  Accuracy: 76.7%, Avg loss: 2.046624
#
# Epoch 99928
# -------------------------------
# Training Error:
#  Accuracy: 92.4%, Avg loss: 0.247089
#
# Test Error:
#  Accuracy: 77.0%, Avg loss: 2.013654
#
# Epoch 99929
# -------------------------------
# Training Error:
#  Accuracy: 92.1%, Avg loss: 0.271774
#
# Test Error:
#  Accuracy: 79.0%, Avg loss: 2.064973
#
# Epoch 99930
# -------------------------------
# Training Error:
#  Accuracy: 93.3%, Avg loss: 0.259307
#
# Test Error:
#  Accuracy: 77.0%, Avg loss: 2.252679
#
# Epoch 99931
# -------------------------------
# Training Error:
#  Accuracy: 93.0%, Avg loss: 0.229676
#
# Test Error:
#  Accuracy: 77.3%, Avg loss: 2.251720
#
# Epoch 99932
# -------------------------------
# Training Error:
#  Accuracy: 92.1%, Avg loss: 0.229907
#
# Test Error:
#  Accuracy: 79.0%, Avg loss: 2.167310
#
# Epoch 99933
# -------------------------------
# Training Error:
#  Accuracy: 92.4%, Avg loss: 0.267218
#
# Test Error:
#  Accuracy: 74.3%, Avg loss: 2.253054
#
# Epoch 99934
# -------------------------------
# Training Error:
#  Accuracy: 91.6%, Avg loss: 0.240778
#
# Test Error:
#  Accuracy: 79.0%, Avg loss: 2.230235
#
# Epoch 99935
# -------------------------------
# Training Error:
#  Accuracy: 92.0%, Avg loss: 0.278766
#
# Test Error:
#  Accuracy: 76.7%, Avg loss: 2.112839
#
# Epoch 99936
# -------------------------------
# Training Error:
#  Accuracy: 92.3%, Avg loss: 0.298531
#
# Test Error:
#  Accuracy: 79.0%, Avg loss: 2.179006
#
# Epoch 99937
# -------------------------------
# Training Error:
#  Accuracy: 92.7%, Avg loss: 0.240205
#
# Test Error:
#  Accuracy: 75.7%, Avg loss: 2.164035
#
# Epoch 99938
# -------------------------------
# Training Error:
#  Accuracy: 92.9%, Avg loss: 0.231522
#
# Test Error:
#  Accuracy: 78.0%, Avg loss: 2.273261
#
# Epoch 99939
# -------------------------------
# Training Error:
#  Accuracy: 92.9%, Avg loss: 0.249537
#
# Test Error:
#  Accuracy: 77.3%, Avg loss: 2.216659
#
# Epoch 99940
# -------------------------------
# Training Error:
#  Accuracy: 92.7%, Avg loss: 0.232627
#
# Test Error:
#  Accuracy: 77.0%, Avg loss: 2.208696
#
# Epoch 99941
# -------------------------------
# Training Error:
#  Accuracy: 90.7%, Avg loss: 0.247709
#
# Test Error:
#  Accuracy: 76.0%, Avg loss: 2.212411
#
# Epoch 99942
# -------------------------------
# Training Error:
#  Accuracy: 91.9%, Avg loss: 0.248131
#
# Test Error:
#  Accuracy: 78.3%, Avg loss: 2.110655
#
# Epoch 99943
# -------------------------------
# Training Error:
#  Accuracy: 92.0%, Avg loss: 0.221383
#
# Test Error:
#  Accuracy: 77.3%, Avg loss: 2.153630
#
# Epoch 99944
# -------------------------------
# Training Error:
#  Accuracy: 90.6%, Avg loss: 0.253108
#
# Test Error:
#  Accuracy: 77.0%, Avg loss: 2.192424
#
# Epoch 99945
# -------------------------------
# Training Error:
#  Accuracy: 91.3%, Avg loss: 0.272346
#
# Test Error:
#  Accuracy: 75.0%, Avg loss: 2.256590
#
# Epoch 99946
# -------------------------------
# Training Error:
#  Accuracy: 92.1%, Avg loss: 0.242413
#
# Test Error:
#  Accuracy: 75.7%, Avg loss: 2.284394
#
# Epoch 99947
# -------------------------------
# Training Error:
#  Accuracy: 92.4%, Avg loss: 0.227114
#
# Test Error:
#  Accuracy: 77.7%, Avg loss: 2.289472
#
# Epoch 99948
# -------------------------------
# Training Error:
#  Accuracy: 91.7%, Avg loss: 0.269644
#
# Test Error:
#  Accuracy: 77.7%, Avg loss: 2.304313
#
# Epoch 99949
# -------------------------------
# Training Error:
#  Accuracy: 92.6%, Avg loss: 0.306243
#
# Test Error:
#  Accuracy: 77.7%, Avg loss: 1.980944
#
# Epoch 99950
# -------------------------------
# Training Error:
#  Accuracy: 92.3%, Avg loss: 0.238177
#
# Test Error:
#  Accuracy: 78.0%, Avg loss: 2.140737
#
# Epoch 99951
# -------------------------------
# Training Error:
#  Accuracy: 91.6%, Avg loss: 0.279613
#
# Test Error:
#  Accuracy: 75.7%, Avg loss: 2.099108
#
# Epoch 99952
# -------------------------------
# Training Error:
#  Accuracy: 91.0%, Avg loss: 0.300725
#
# Test Error:
#  Accuracy: 76.7%, Avg loss: 2.272636
#
# Epoch 99953
# -------------------------------
# Training Error:
#  Accuracy: 92.1%, Avg loss: 0.235141
#
# Test Error:
#  Accuracy: 75.7%, Avg loss: 2.254649
#
# Epoch 99954
# -------------------------------
# Training Error:
#  Accuracy: 91.3%, Avg loss: 0.244746
#
# Test Error:
#  Accuracy: 73.7%, Avg loss: 2.428559
#
# Epoch 99955
# -------------------------------
# Training Error:
#  Accuracy: 93.9%, Avg loss: 0.245225
#
# Test Error:
#  Accuracy: 78.7%, Avg loss: 2.264715
#
# Epoch 99956
# -------------------------------
# Training Error:
#  Accuracy: 92.3%, Avg loss: 0.200840
#
# Test Error:
#  Accuracy: 75.7%, Avg loss: 2.357068
#
# Epoch 99957
# -------------------------------
# Training Error:
#  Accuracy: 92.1%, Avg loss: 0.233908
#
# Test Error:
#  Accuracy: 78.0%, Avg loss: 2.230549
#
# Epoch 99958
# -------------------------------
# Training Error:
#  Accuracy: 92.0%, Avg loss: 0.233107
#
# Test Error:
#  Accuracy: 76.0%, Avg loss: 2.400678
#
# Epoch 99959
# -------------------------------
# Training Error:
#  Accuracy: 92.0%, Avg loss: 0.262710
#
# Test Error:
#  Accuracy: 77.3%, Avg loss: 2.389026
#
# Epoch 99960
# -------------------------------
# Training Error:
#  Accuracy: 92.6%, Avg loss: 0.219526
#
# Test Error:
#  Accuracy: 77.0%, Avg loss: 2.229077
#
# Epoch 99961
# -------------------------------
# Training Error:
#  Accuracy: 91.9%, Avg loss: 0.250891
#
# Test Error:
#  Accuracy: 78.7%, Avg loss: 2.162835
#
# Epoch 99962
# -------------------------------
# Training Error:
#  Accuracy: 92.4%, Avg loss: 0.218137
#
# Test Error:
#  Accuracy: 75.7%, Avg loss: 2.222709
#
# Epoch 99963
# -------------------------------
# Training Error:
#  Accuracy: 91.0%, Avg loss: 0.301253
#
# Test Error:
#  Accuracy: 78.3%, Avg loss: 2.325713
#
# Epoch 99964
# -------------------------------
# Training Error:
#  Accuracy: 92.7%, Avg loss: 0.266726
#
# Test Error:
#  Accuracy: 76.3%, Avg loss: 2.447014
#
# Epoch 99965
# -------------------------------
# Training Error:
#  Accuracy: 91.6%, Avg loss: 0.249261
#
# Test Error:
#  Accuracy: 78.3%, Avg loss: 2.259562
#
# Epoch 99966
# -------------------------------
# Training Error:
#  Accuracy: 90.1%, Avg loss: 0.321707
#
# Test Error:
#  Accuracy: 75.0%, Avg loss: 1.984902
#
# Epoch 99967
# -------------------------------
# Training Error:
#  Accuracy: 91.3%, Avg loss: 0.358942
#
# Test Error:
#  Accuracy: 77.0%, Avg loss: 2.408082
#
# Epoch 99968
# -------------------------------
# Training Error:
#  Accuracy: 89.6%, Avg loss: 0.315409
#
# Test Error:
#  Accuracy: 75.3%, Avg loss: 2.222792
#
# Epoch 99969
# -------------------------------
# Training Error:
#  Accuracy: 91.1%, Avg loss: 0.234036
#
# Test Error:
#  Accuracy: 73.7%, Avg loss: 2.337399
#
# Epoch 99970
# -------------------------------
# Training Error:
#  Accuracy: 93.0%, Avg loss: 0.227183
#
# Test Error:
#  Accuracy: 77.7%, Avg loss: 2.411883
#
# Epoch 99971
# -------------------------------
# Training Error:
#  Accuracy: 91.6%, Avg loss: 0.269173
#
# Test Error:
#  Accuracy: 74.3%, Avg loss: 2.343593
#
# Epoch 99972
# -------------------------------
# Training Error:
#  Accuracy: 90.9%, Avg loss: 0.253676
#
# Test Error:
#  Accuracy: 79.0%, Avg loss: 2.389990
#
# Epoch 99973
# -------------------------------
# Training Error:
#  Accuracy: 91.9%, Avg loss: 0.277965
#
# Test Error:
#  Accuracy: 75.3%, Avg loss: 2.347972
#
# Epoch 99974
# -------------------------------
# Training Error:
#  Accuracy: 91.9%, Avg loss: 0.247915
#
# Test Error:
#  Accuracy: 79.3%, Avg loss: 2.245176
#
# Epoch 99975
# -------------------------------
# Training Error:
#  Accuracy: 93.0%, Avg loss: 0.222826
#
# Test Error:
#  Accuracy: 77.7%, Avg loss: 2.231884
#
# Epoch 99976
# -------------------------------
# Training Error:
#  Accuracy: 92.3%, Avg loss: 0.258745
#
# Test Error:
#  Accuracy: 78.0%, Avg loss: 2.229985
#
# Epoch 99977
# -------------------------------
# Training Error:
#  Accuracy: 92.1%, Avg loss: 0.254576
#
# Test Error:
#  Accuracy: 76.3%, Avg loss: 2.249599
#
# Epoch 99978
# -------------------------------
# Training Error:
#  Accuracy: 92.7%, Avg loss: 0.247064
#
# Test Error:
#  Accuracy: 76.3%, Avg loss: 2.327215
#
# Epoch 99979
# -------------------------------
# Training Error:
#  Accuracy: 92.6%, Avg loss: 0.228952
#
# Test Error:
#  Accuracy: 78.7%, Avg loss: 2.393052
#
# Epoch 99980
# -------------------------------
# Training Error:
#  Accuracy: 92.4%, Avg loss: 0.268683
#
# Test Error:
#  Accuracy: 76.7%, Avg loss: 2.270320
#
# Epoch 99981
# -------------------------------
# Training Error:
#  Accuracy: 91.9%, Avg loss: 0.257864
#
# Test Error:
#  Accuracy: 77.3%, Avg loss: 2.257277
#
# Epoch 99982
# -------------------------------
# Training Error:
#  Accuracy: 91.4%, Avg loss: 0.260835
#
# Test Error:
#  Accuracy: 79.3%, Avg loss: 2.075121
#
# Epoch 99983
# -------------------------------
# Training Error:
#  Accuracy: 92.1%, Avg loss: 0.245625
#
# Test Error:
#  Accuracy: 76.3%, Avg loss: 2.083826
#
# Epoch 99984
# -------------------------------
# Training Error:
#  Accuracy: 92.4%, Avg loss: 0.246662
#
# Test Error:
#  Accuracy: 78.3%, Avg loss: 2.165612
#
# Epoch 99985
# -------------------------------
# Training Error:
#  Accuracy: 92.7%, Avg loss: 0.255514
#
# Test Error:
#  Accuracy: 79.3%, Avg loss: 2.198854
#
# Epoch 99986
# -------------------------------
# Training Error:
#  Accuracy: 92.6%, Avg loss: 0.223085
#
# Test Error:
#  Accuracy: 76.7%, Avg loss: 2.135462
#
# Epoch 99987
# -------------------------------
# Training Error:
#  Accuracy: 92.6%, Avg loss: 0.222080
#
# Test Error:
#  Accuracy: 78.0%, Avg loss: 2.224397
#
# Epoch 99988
# -------------------------------
# Training Error:
#  Accuracy: 93.3%, Avg loss: 0.221642
#
# Test Error:
#  Accuracy: 77.3%, Avg loss: 2.168981
#
# Epoch 99989
# -------------------------------
# Training Error:
#  Accuracy: 92.3%, Avg loss: 0.261580
#
# Test Error:
#  Accuracy: 78.3%, Avg loss: 2.174745
#
# Epoch 99990
# -------------------------------
# Training Error:
#  Accuracy: 93.6%, Avg loss: 0.217868
#
# Test Error:
#  Accuracy: 77.7%, Avg loss: 2.296052
#
# Epoch 99991
# -------------------------------
# Training Error:
#  Accuracy: 92.7%, Avg loss: 0.227825
#
# Test Error:
#  Accuracy: 79.0%, Avg loss: 2.136899
#
# Epoch 99992
# -------------------------------
# Training Error:
#  Accuracy: 92.4%, Avg loss: 0.333563
#
# Test Error:
#  Accuracy: 77.7%, Avg loss: 2.171145
#
# Epoch 99993
# -------------------------------
# Training Error:
#  Accuracy: 92.6%, Avg loss: 0.270630
#
# Test Error:
#  Accuracy: 78.7%, Avg loss: 2.099607
#
# Epoch 99994
# -------------------------------
# Training Error:
#  Accuracy: 91.9%, Avg loss: 0.241766
#
# Test Error:
#  Accuracy: 76.0%, Avg loss: 2.123468
#
# Epoch 99995
# -------------------------------
# Training Error:
#  Accuracy: 92.1%, Avg loss: 0.244208
#
# Test Error:
#  Accuracy: 78.0%, Avg loss: 2.098270
#
# Epoch 99996
# -------------------------------
# Training Error:
#  Accuracy: 91.1%, Avg loss: 0.248592
#
# Test Error:
#  Accuracy: 76.3%, Avg loss: 2.256733
#
# Epoch 99997
# -------------------------------
# Training Error:
#  Accuracy: 93.1%, Avg loss: 0.240182
#
# Test Error:
#  Accuracy: 79.0%, Avg loss: 1.931737
#
# Epoch 99998
# -------------------------------
# Training Error:
#  Accuracy: 91.4%, Avg loss: 0.291113
#
# Test Error:
#  Accuracy: 79.0%, Avg loss: 2.236324
#
# Epoch 99999
# -------------------------------
# Training Error:
#  Accuracy: 92.0%, Avg loss: 0.269816
#
# Test Error:
#  Accuracy: 77.0%, Avg loss: 2.293691
#
# Epoch 100000
# -------------------------------
# Training Error:
#  Accuracy: 91.6%, Avg loss: 0.282953
#
# Test Error:
#  Accuracy: 77.3%, Avg loss: 2.184993
#
# Done!

# %%
# %matplotlib inline
import numpy as np

animator.display_plt()
# Automate improved filename description.
animator.fig.savefig('loss.png', bbox_inches='tight')
# plt.savefig('loss.png', bbox_inches='tight')   # Less specific. Targets active figure.

# pipe labels are located in data to csv notebook
# predictions = [f'{i}' for i in range(output_dim)]
predictions = decode_labels()
# labels = range(output_dim)
labels = decode_labels()
fig, ax = plt.subplots(1, 1, figsize=(4,4))
# fig.set_facecolor('#7d7f7c')
im = ax.imshow(confusion_matrix)
ax.set_xticks(np.arange(len(predictions)))
ax.set_yticks(np.arange(len(labels)))
ax.set_xticklabels(predictions)
ax.set_yticklabels(labels)

# Set-up for white grid lines on minor ticks. Creates spacing effect.
ax.set_xticks(np.arange(len(predictions)+1) - 0.5, minor=True)
ax.set_yticks(np.arange(len(labels)+1) - 0.5, minor=True)
# Print white grid to space out the squares.
ax.grid(which="minor", color="w", linestyle='-', linewidth=1)
# Remove spines for clarity.
for k, v in ax.spines.items() :
  v.set_visible(False)
# ax.spines['top'].set_visible(False)   # Can't slice a dictionary.
ax.tick_params(which="minor", bottom=False, left=False)

# Horizontal labeling displays on top
ax.tick_params(top=True, bottom=False, labeltop=True, labelbottom=False)
# Rotate tick labels and set alignment.
plt.setp(ax.get_xticklabels(), rotation=-45, ha='right', rotation_mode='anchor')
plt.xlabel(f'Predictions -- {ts_size}')
# Move the x labels to the top
ax.xaxis.set_label_position('top')
plt.ylabel('Labels')
# Annotate matrix with values by looping over data dimensions
for i in range(len(labels)) :
  for j in range(len(predictions)) :
    text = ax.text(j, i, confusion_matrix[i, j].item(),
                   ha='center', va='center', color='white')

ax.set_title(f'Confusion Matrix -- Epoch {t+1}')
fig.tight_layout()
# Save to file that is replaced on every run.
fig.savefig('conf.png')
# plt.show()
# plt.close()

# %%
#torch.save(model.state_dict(), f'/content/drive/MyDrive/Colab Notebooks/Water Distribution Network/Decoder/saved_models/midTrainingModel.pt')

# %% [markdown]
# ####Sanity Check: Pass a sample to the model

# %%
def predict_ch3(net, sample, samp_idx=0):
    """Predict labels (redefined from d2l Chapter 3.6.7)."""
    print('Model Evaluation')
    X, y = sample[samp_idx]
    X = X.reshape([1,-1])
    preds = net(X).argmax(axis=1)
    print(f'Scenario {samp_idx} (pred={preds.item()}, label={y.item()})')

predict_ch3(model, tr_dataset, samp_idx=28)
# Out:
# Model Evaluation
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-56cc4abdd59a> in <module>()
#       7     print(f'Scenario {samp_idx} (pred={preds.item()}, label={y.item()})')
#       8
# ----> 9 predict_ch3(model, tr_dataset, samp_idx=28)
#
# <ipython-input-26-56cc4abdd59a> in predict_ch3(net, sample, samp_idx)
#       4     X, y = sample[samp_idx]
#       5     X = X.reshape([1,-1])
# ----> 6     preds = net(X).argmax(axis=1)
#       7     print(f'Scenario {samp_idx} (pred={preds.item()}, label={y.item()})')
#       8
#
# AttributeError: 'tuple' object has no attribute 'argmax'

# %%
# Test trained model on time stamps it hasn't seen before
# tmstp = 168
# X, y = cat_data(residual, norm_base, norm_feats, mask, net_char, tmstp)
# ts_dataset = TensorDataset(X, y)

# test_dataloader = DataLoader(ts_dataset, batch_size=batch_size)
# test_acc = test_loop(test_dataloader, model, loss_fn)

# %% [markdown]
# ####Scratch Work

# %%
print(0.991 > 0.99)
x = torch.rand(5)
print(x)
y = torch.where(x > 0.6, x, torch.tensor(0.))
print(y)

# %%
import math
x = float('nan')
print(x)
print(not math.isnan(x))
print(1 + 0.0 * x)
print(torch.log(torch.tensor(0.0)))

# %%
x_tup = ([2], [3], [4])
# x_tup = (2, 3, 4)
x_tup[1][0] -= x_tup[0][0]
# x_tup[1] -= x_tup[0]
# print(x_tup[1] - x_tup[0])
print(x_tup[1])

# %%
t = torch.rand(10, generator=torch.Generator().manual_seed(10))
print(t)
t1 = torch.rand(10, generator=torch.Generator().manual_seed(11))
print(t1)
print(t[t1 > 0.5])   # returns a tensor containing only those elems for which test returns true.
t[t1 > 0.5] = 0   # Assigns zero to only those elems for which the test returns true.
print(t)
print(t[t1 > 0.5])
print(t[0])   # Returns a zero dim tensor. (num)
print(t[0:1])   # Returns a 1-dim tensor. ([num])
print(t[0:1].new(1))
print(t[0:1].new_empty(1).uniform_())

# %%
t = torch.rand(10, generator=torch.Generator().manual_seed(10))
print(' t:', t)
idxs = torch.randperm(5, generator=torch.Generator().manual_seed(10))
print(idxs)
tn = t[idxs]
print(' t:', t)
print('tn:', tn)
print(' t:', t[2])
print('tn:', tn[0])

# %%
y_hat = torch.arange(20).reshape([2, -1])
print(y_hat)
len(y_hat)
print(y_hat.sum(1))
print(y_hat.argmax(dim=0))
print(y_hat.argmax(dim=1))
data = [[1.0, 1.0], [1.0, 1.0]] * 2   # multiplies the number of elements (like if you had 2 apples and then multiplied them by 2; you now have four apples)
print(data)
# print(data / data)   # dividing a list is not defined
(1,2) + (3,)   # cats the three elems
len((1,2))   # tuples have __len__ defined
[[] for _ in range(3)]
rows = [[1,1]]
print(rows)
[rows.append(i) for i in [[3,3],[4,4]]]
print(rows)

# %%
# X_masked = None
# masked_feats = torch.rand(15)
# print(masked_feats)
# mask = torch.randint(2, [15])
# print(mask)
# # Mask and masked features
# # May want sensing_mask_rand() to process batches of samples
# for i in range(5):
#   temp = torch.cat((masked_feats, mask)).reshape([1,-1])
#   print(temp)

#   if X_masked is None:
#     X_masked = temp   
#     print(X_masked)
#   else:  
#     X_masked = torch.cat((X_masked, temp))
#     print(X_masked)

# for i in X_masked:
#   print(i)

# %%
# size = [100,]
# K = 20
# tn = torch.zeros(size)
# mask = torch.zeros(tn.size())
# print(mask.size())
# print(mask)
# indices = torch.randint(len(tn), size=(K,))
# print(indices)
# for idx in indices:
#   mask[idx] = 1
# print(mask)

# mask = torch.cuda.FloatTensor(3, 3).uniform_()
# # tensor of floats
# mask = torch.FloatTensor(3,3).uniform_()
# print(mask)
# # tensor of booleans (?? how ??)
# mask = torch.FloatTensor(3,3).uniform_() > 0.8
# print(mask)

# %%
# converting string labs to labels ranging from 0 -> num_of_classes (i.e. possible leak locations)
#  what if not all of the possible leak locations are used?
#  1) I can set the output dim to len of label_subset (easiser)
#  2) I can force the set to be all the possible fixed pipe locations (coordinating this will be tricky)
# labs = [1,2,2,3,1,4,4,3]
# lab_dict = {}
# encoded_labs = []
# label_subset = set(labs)
# print(label_subset)
# print(type(label_subset))
# print(len(label_subset))
# for i, key in enumerate(label_subset):
#   lab_dict[key] = i
# print(lab_dict)
# for key in labs:
#   encoded_labs.append(lab_dict[key])
# print(encoded_labs)

# %%
# Reshaping practice
# base_file = 'simdata/_base_/node_demand.csv'
# data_file = base_file
# data = pd.read_csv(data_file)
# data_tn = torch.tensor(data.values, dtype=torch.float32)
# data_tn[:,1:].reshape([1,-1])

# data_tn = torch.arange(20).reshape([4,5])
# print(data_tn)
# data_tn = data_tn[:,1:].reshape([1,-1])
# print(data_tn)
# data_tn1 = torch.arange(20).reshape([4,5])
# print(data_tn1)
# data_tn1 = data_tn1[:,1:].reshape([1, -1])
# print(data_tn1)
# torch.cat((data_tn1, data_tn))

# %%
# Extracting an intelligible answer from the model
# x = torch.arange(16, dtype=torch.float32).reshape((4,4))
# print(x)
# print(x.sum(axis=0))
# print(x.sum(axis=[0,1]))
# mean = x.sum() / x.numel()
# print(mean)
# # notice we keep all dims (tensor of a tensor ie. two brackets) vs above we lost one (just a tensor)
# print(x.sum(dim=0, keepdim=True))

# y = torch.tensor([3,3,3,3])
# # x.argmax(1).type(y.dtype) == y
# correct = 0
# correct += (x.argmax(1).type(y.dtype) == y).type(torch.float32).sum().item()
# correct

# %%
# Handy timer class
class Timer:
    """Record multiple running times."""
    def __init__(self):
        self.times = []
        self.start()

    def start(self):
        """Start the timer."""
        self.tik = time.time()

    def stop(self):
        """Stop the timer and record the time in a list."""
        self.times.append(time.time() - self.tik)
        return self.times[-1]

    def avg(self):
        """Return the average time."""
        return sum(self.times) / len(self.times)

    def sum(self):
        """Return the sum of time."""
        return sum(self.times)

    def cumsum(self):
        """Return the accumulated time."""
        return np.array(self.times).cumsum().tolist()

# %%
# Target transform
from torchvision.transforms import Lambda

train_size = 700
# target_transform = Lambda(lambda y: torch.zeros(
#     (train_size, output_dim), dtype=torch.float).scatter_(
#         dim=1, index=torch.randint(low=0,high=output_dim,size=[train_size,1]), value=1))

# one-hot classification label vector
target_transform = Lambda(lambda y: torch.scatter_(
        dim=1, index=torch.randint(low=0,high=output_dim,size=[train_size,1]), value=1))
